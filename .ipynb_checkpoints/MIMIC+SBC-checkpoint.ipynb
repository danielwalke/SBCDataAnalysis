# %%
from dataAnalysis.DataAnalysis import DataAnalysis
import pandas as pd
from dataAnalysis.Constants import FEATURES, SEX_CATEGORY_COLUMN_NAME, FEATURES_IN_TABLE

data = pd.read_csv(r"extdata/sbcdata.csv", header=0)
data_analysis = DataAnalysis(data)
mimic_sbc = pd.read_csv("hosp_mimic_i.csv")
# Out:
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Training:
# Assessable data are 528101 cases and 1015074 CBCs
# Control data are 527038 cases and 1013548 CBCs
# Sepsis data are 1488 cases and 1526 CBCs
# $$$$$$$$$$$$$$$$$$$$
# Testing:
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 365794, Sepsis: 490
# Assessable data are 180494 cases and 366284 CBCs
# Control data are 180157 cases and 365794 CBCs
# Sepsis data are 472 cases and 490 CBCs
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 437629, Sepsis: 448
# Assessable data are 157922 cases and 438077 CBCs
# Control data are 180157 cases and 437629 CBCs
# Sepsis data are 438 cases and 448 CBCs

# %%
mimic_sbc = mimic_sbc.dropna(subset=FEATURES_IN_TABLE)
mimic_sbc.loc[:, SEX_CATEGORY_COLUMN_NAME] = mimic_sbc["Sex"] == "W"
mimic_sbc[SEX_CATEGORY_COLUMN_NAME] = mimic_sbc[SEX_CATEGORY_COLUMN_NAME].astype(int)

# %%
X_sbc = data_analysis.get_X_train() 
X_mimic = mimic_sbc.loc[:, FEATURES].values

X_test = data_analysis.get_X_test()
X_gw_test = data_analysis.get_X_gw()

y_sbc = data_analysis.get_y_train()
y_mimic = mimic_sbc.loc[:,"Label"].values
y_test = data_analysis.get_y_test()
y_gw_test = data_analysis.get_y_gw()

# %%
import numpy as np
X = np.concatenate((X_sbc, X_mimic), axis = 0)
y = np.concatenate((y_sbc, y_mimic), axis = 0)

# %%
import numpy as np
unique, counts = np.unique(y, return_counts=True)

# %%
from dataAnalysis.Metrics import Evaluation

evaluation = Evaluation(y_test, y_gw_test, X_test, X_gw_test)
# Out:
# /home/dwalke/.local/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
from sklearn.model_selection import GridSearchCV

def get_best_estimator(model, param_grid):
    grid = GridSearchCV(
    n_jobs=-1,
    cv=10,
    estimator=model,
    scoring='roc_auc',
    refit='auroc',
    return_train_score=True,
    param_grid=param_grid,
    verbose= 10
    )
    grid.fit(X, y)
    return grid.best_estimator_

# %%
counts[0]/ counts[1]
# Out:
# 42.12101505509855

# %%
from xgboost import XGBClassifier
param_grid = {
    'max_depth': [8, 10],
    'learning_rate': [0.1],
    'gamma': [0],
    'reg_lambda': [0, 1, 10],
    'scale_pos_weight': [i for i in range(10, 140, 10)],
    "min_child_weight": [2],
    "max_delta_step": [2],
    'n_estimators': [700]
}
xgb_classifier = get_best_estimator(XGBClassifier(tree_method='gpu_hist', gpu_id = 2,
                                                        seed = 42), param_grid)
# Out:
# Fitting 10 folds for each of 78 candidates, totalling 780 fits
# [CV 5/10; 6/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60
# [CV 5/10; 6/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60;, score=(train=nan, test=nan) total time=  13.1s
# [CV 8/10; 7/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70
# [CV 8/10; 7/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   4.6s
# [CV 7/10; 8/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80
# [CV 7/10; 8/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 9/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90
# [CV 7/10; 9/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 10/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100
# [CV 8/10; 10/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 11/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110
# [CV 9/10; 11/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 12/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120
# [CV 10/10; 12/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.9s
# [CV 2/10; 14/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10
# [CV 2/10; 14/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 15/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20
# [CV 3/10; 15/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 16/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30
# [CV 4/10; 16/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 17/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40
# [CV 5/10; 17/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 18/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50
# [CV 6/10; 18/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 19/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60
# [CV 7/10; 19/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 20/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70
# [CV 8/10; 20/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   3.9s
# [CV 9/10; 21/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80
# [CV 9/10; 21/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 22/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90
# [CV 10/10; 22/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 24/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110
# [CV 1/10; 24/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 25/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120
# [CV 2/10; 25/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 26/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130
# [CV 3/10; 26/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 27/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10
# [CV 4/10; 27/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 28/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20
# [CV 5/10; 28/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.9s
# [CV 6/10; 29/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30
# [CV 6/10; 29/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.9s
# [CV 7/10; 30/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40
# [CV 7/10; 30/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 5/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50
# [CV 9/10; 5/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50;, score=(train=nan, test=nan) total time=  13.1s
# [CV 5/10; 7/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70
# [CV 5/10; 7/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   5.3s
# [CV 10/10; 8/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80
# [CV 10/10; 8/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 10/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100
# [CV 1/10; 10/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.7s
# [CV 2/10; 11/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110
# [CV 2/10; 11/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.7s
# [CV 2/10; 12/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120
# [CV 2/10; 12/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 13/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130
# [CV 3/10; 13/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 14/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10
# [CV 4/10; 14/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 15/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20
# [CV 5/10; 15/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 16/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30
# [CV 6/10; 16/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 17/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40
# [CV 7/10; 17/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 18/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50
# [CV 7/10; 18/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 19/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60
# [CV 8/10; 19/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 20/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70
# [CV 9/10; 20/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 21/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80
# [CV 10/10; 21/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 23/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100
# [CV 1/10; 23/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 24/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110
# [CV 2/10; 24/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 25/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120
# [CV 3/10; 25/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 26/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130
# [CV 4/10; 26/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 27/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10
# [CV 5/10; 27/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 28/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20
# [CV 6/10; 28/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 29/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30
# [CV 7/10; 29/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 30/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40
# [CV 8/10; 30/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 7/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70
# [CV 4/10; 7/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70;, score=(train=nan, test=nan) total time=  13.5s
# [CV 10/10; 7/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70
# [CV 10/10; 7/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   4.8s
# [CV 1/10; 9/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90
# [CV 1/10; 9/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 10/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100
# [CV 2/10; 10/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 11/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110
# [CV 3/10; 11/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 12/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120
# [CV 4/10; 12/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 13/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130
# [CV 7/10; 13/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 14/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10
# [CV 7/10; 14/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 15/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20
# [CV 7/10; 15/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 16/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30
# [CV 9/10; 16/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 17/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40
# [CV 9/10; 17/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 19/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60
# [CV 1/10; 19/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 19/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60
# [CV 10/10; 19/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 21/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80
# [CV 3/10; 21/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 22/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90
# [CV 5/10; 22/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 23/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100
# [CV 5/10; 23/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 24/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110
# [CV 6/10; 24/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 25/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120
# [CV 8/10; 25/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 26/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130
# [CV 8/10; 26/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 27/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10
# [CV 8/10; 27/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 28/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20
# [CV 10/10; 28/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 29/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30
# [CV 8/10; 29/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 30/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40
# [CV 10/10; 30/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 5/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50
# [CV 8/10; 5/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50;, score=(train=nan, test=nan) total time=  13.6s
# [CV 3/10; 8/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80
# [CV 3/10; 8/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   4.8s
# [CV 2/10; 9/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90
# [CV 2/10; 9/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 10/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100
# [CV 3/10; 10/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 11/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110
# [CV 4/10; 11/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 12/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120
# [CV 6/10; 12/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 13/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130
# [CV 6/10; 13/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 14/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10
# [CV 8/10; 14/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 15/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20
# [CV 8/10; 15/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 16/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30
# [CV 10/10; 16/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 18/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50
# [CV 1/10; 18/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 19/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60
# [CV 2/10; 19/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 20/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70
# [CV 3/10; 20/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 21/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80
# [CV 4/10; 21/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 22/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90
# [CV 4/10; 22/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 23/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100
# [CV 6/10; 23/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 24/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110
# [CV 7/10; 24/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 25/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120
# [CV 7/10; 25/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 26/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130
# [CV 9/10; 26/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 27/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10
# [CV 10/10; 27/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 29/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30
# [CV 1/10; 29/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 29/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30
# [CV 10/10; 29/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 31/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=50
# [CV 1/10; 31/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=50;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 6/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60
# [CV 1/10; 6/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60;, score=(train=nan, test=nan) total time=  13.1s
# [CV 7/10; 7/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70
# [CV 7/10; 7/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   4.2s
# [CV 6/10; 8/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80
# [CV 6/10; 8/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   4.3s
# [CV 8/10; 9/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90
# [CV 8/10; 9/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.9s
# [CV 9/10; 10/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100
# [CV 9/10; 10/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.9s
# [CV 1/10; 12/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120
# [CV 1/10; 12/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 13/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130
# [CV 2/10; 13/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 14/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10
# [CV 3/10; 14/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 15/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20
# [CV 4/10; 15/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 16/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30
# [CV 5/10; 16/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 17/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40
# [CV 6/10; 17/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.9s
# [CV 8/10; 18/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50
# [CV 8/10; 18/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 19/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60
# [CV 9/10; 19/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60;, score=(train=nan, test=nan) total time=   3.9s
# [CV 2/10; 21/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80
# [CV 2/10; 21/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 22/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90
# [CV 2/10; 22/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 23/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100
# [CV 2/10; 23/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 24/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110
# [CV 3/10; 24/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 25/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120
# [CV 4/10; 25/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 26/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130
# [CV 7/10; 26/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.9s
# [CV 9/10; 27/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10
# [CV 9/10; 27/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 28/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20
# [CV 9/10; 28/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 29/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30
# [CV 9/10; 29/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=30;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 30/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40
# [CV 9/10; 30/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.9s
# [CV 1/10; 3/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=30
# [CV 1/10; 3/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=30;, score=(train=nan, test=nan) total time=  13.5s
# [CV 2/10; 8/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80
# [CV 2/10; 8/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   4.9s
# [CV 4/10; 9/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90
# [CV 4/10; 9/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 10/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100
# [CV 5/10; 10/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 11/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110
# [CV 6/10; 11/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 12/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120
# [CV 7/10; 12/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.9s
# [CV 8/10; 13/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130
# [CV 8/10; 13/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 14/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10
# [CV 9/10; 14/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=10;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 15/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20
# [CV 10/10; 15/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=20;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 17/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40
# [CV 1/10; 17/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=40;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 18/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50
# [CV 2/10; 18/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=50;, score=(train=nan, test=nan) total time=   3.8s
# [CV 3/10; 19/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60
# [CV 3/10; 19/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=60;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 20/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70
# [CV 4/10; 20/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=70;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 21/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80
# [CV 5/10; 21/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=80;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 22/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90
# [CV 6/10; 22/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=90;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 23/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100
# [CV 7/10; 23/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=100;, score=(train=nan, test=nan) total time=   3.8s
# [CV 8/10; 24/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110
# [CV 8/10; 24/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=110;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 25/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120
# [CV 9/10; 25/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=120;, score=(train=nan, test=nan) total time=   3.8s
# [CV 10/10; 26/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130
# [CV 10/10; 26/78] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=1, scale_pos_weight=130;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 28/78] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=10, scale_pos_weight=20
# ...
#
#
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x71ee69) [0x7f1fbbd1ee69]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73d908) [0x7f1fbbd3d908]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a2699) [0x7f1fbb8a2699]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a33ed) [0x7f1fbb8a33ed]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ddce7) [0x7f1fbb8ddce7]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x7f1fbb72df90]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x7f1fd708de2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x7f1fd708a493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa451) [0x7f1fd3cbf451]
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dwalke/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:34:48] ../src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [07:34:48] ../src/c_api/../data/../common/device_helpers.cuh:431: Memory allocation error on worker 0: std::bad_alloc: cudaErrorMemoryAllocation: out of memory
# - Free memory: 14090240
# - Requested memory: 20003672
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x455329) [0x7fafa3255329]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x45a198) [0x7fafa325a198]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0xf7b5d) [0x7fafa2ef7b5d]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4eda31) [0x7fafa32eda31]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4ec5ac) [0x7fafa32ec5ac]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x50227c) [0x7fafa330227c]
#   [bt] (6) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73766f) [0x7fafa353766f]
#   [bt] (7) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73d710) [0x7fafa353d710]
#   [bt] (8) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a2699) [0x7fafa30a2699]
#
#
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x71ee69) [0x7fafa351ee69]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73d908) [0x7fafa353d908]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a2699) [0x7fafa30a2699]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a33ed) [0x7fafa30a33ed]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ddce7) [0x7fafa30ddce7]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x7fafa2f2df90]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x7fafbe815e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x7fafbe812493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa451) [0x7fafbd6bb451]
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dwalke/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:34:48] ../src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [07:34:48] ../src/c_api/../data/../common/device_helpers.cuh:431: Memory allocation error on worker 0: std::bad_alloc: cudaErrorMemoryAllocation: out of memory
# - Free memory: 14090240
# - Requested memory: 20003680
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x455329) [0x7fc73e055329]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x45a198) [0x7fc73e05a198]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0xf7b5d) [0x7fc73dcf7b5d]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4eda31) [0x7fc73e0eda31]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4ec5ac) [0x7fc73e0ec5ac]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x50227c) [0x7fc73e10227c]
#   [bt] (6) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73766f) [0x7fc73e33766f]
#   [bt] (7) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73d710) [0x7fc73e33d710]
#   [bt] (8) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a2699) [0x7fc73dea2699]
#
#
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x71ee69) [0x7fc73e31ee69]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73d908) [0x7fc73e33d908]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a2699) [0x7fc73dea2699]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a33ed) [0x7fc73dea33ed]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ddce7) [0x7fc73deddce7]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x7fc73dd2df90]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x7fc759594e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x7fc759591493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa451) [0x7fc7562bf451]
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dwalke/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:34:49] ../src/c_api/../data/../common/device_helpers.cuh:431: Memory allocation error on worker 0: std::bad_alloc: cudaErrorMemoryAllocation: out of memory
# - Free memory: 7798784
# - Requested memory: 10001836
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x455329) [0x7f2ce5a55329]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x45a198) [0x7f2ce5a5a198]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4978e9) [0x7f2ce5a978e9]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4ae0d4) [0x7f2ce5aae0d4]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4aff50) [0x7f2ce5aaff50]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4b004b) [0x7f2ce5ab004b]
#   [bt] (6) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x6a9eb8) [0x7f2ce5ca9eb8]
#   [bt] (7) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ddc78) [0x7f2ce58ddc78]
#   [bt] (8) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x7f2ce572df90]
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dwalke/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "/home/dwalke/.local/lib/python3.10/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:34:49] ../src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [07:34:49] ../src/c_api/../data/../common/device_helpers.cuh:431: Memory allocation error on worker 0: std::bad_alloc: cudaErrorMemoryAllocation: out of memory
# - Free memory: 14090240
# - Requested memory: 20003680
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x455329) [0x7ffa80855329]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x45a198) [0x7ffa8085a198]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0xf7b5d) [0x7ffa804f7b5d]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4eda31) [0x7ffa808eda31]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x4ec5ac) [0x7ffa808ec5ac]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x50227c) [0x7ffa8090227c]
#   [bt] (6) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73766f) [0x7ffa80b3766f]
#   [bt] (7) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73d710) [0x7ffa80b3d710]
#   [bt] (8) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a2699) [0x7ffa806a2699]
#
#
#
# Stack trace:
#   [bt] (0) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x71ee69) [0x7ffa80b1ee69]
#   [bt] (1) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x73d908) [0x7ffa80b3d908]
#   [bt] (2) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a2699) [0x7ffa806a2699]
#   [bt] (3) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2a33ed) [0x7ffa806a33ed]
#   [bt] (4) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(+0x2ddce7) [0x7ffa806ddce7]
#   [bt] (5) /home/dwalke/.local/lib/python3.10/site-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x7ffa8052df90]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x7ffa9be16e2e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x7ffa9be13493]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa451) [0x7ffa9acbc451]
#
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dwalke/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.79295414        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /home/dwalke/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the train scores are non-finite: [0.94289146        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(

# %%
xgb_classifier.scale_pos_weight, xgb_classifier.reg_lambda
# Out:
# (10, 0)

# %%
from xgboost import XGBClassifier
xgb_classifier_model = XGBClassifier(tree_method='gpu_hist', 
                           scale_pos_weight = 300,
                           n_estimators=10,
                           max_depth=8,
                           eta=0.1,
                                     gamma=0,
                                     reg_lambda=0,
                           min_child_weight = 2,
                           max_delta_step= 2,
                           sampling_method= "uniform")
xgb_classifier_model.fit(X, y)
print(evaluation.get_df_metrics(xgb_classifier_model))
evaluation.plot_confusion_matrix(xgb_classifier_model)
# Out:
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.028822  0.490660  0.331242   0.004727  0.802366  0.006612
# 1  Greifswald  0.018271  0.367556  0.269919   0.002929  0.740886  0.002917

# %%
import time 

for i in range(10000):
    print("Sleep")
    time.sleep(60)
# Out:
# [CV 4/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 3/10; 629/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 3/10; 629/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 1/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 1/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.995, test=0.902) total time= 9.1min
# [CV 7/10; 587/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 10/10; 587/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 587/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 1/10; 588/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 1/10; 588/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 4/10; 588/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 4/10; 588/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 7/10; 588/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 7/10; 588/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 1/10; 589/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 1/10; 589/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 4/10; 589/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 589/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 7/10; 589/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 589/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 2/10; 590/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 590/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.911) total time=14.9min
# [CV 5/10; 285/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=8, min_child_weight=7, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.967, test=0.684) total time= 8.9min
# [CV 7/10; 407/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 7/10; 407/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.621) total time=19.4min
# [CV 3/10; 591/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 591/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.3s
# [CV 9/10; 591/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 591/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.658) total time=15.4min
# [CV 7/10; 626/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 7/10; 626/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 627/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 7/10; 627/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 629/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 7/10; 629/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 4/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 8/10; 631/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 631/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.623) total time=10.0min
# [CV 2/10; 390/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 390/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 8/10; 391/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 391/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 3/10; 393/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 393/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.938) total time=13.3min
# [CV 2/10; 547/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 2/10; 547/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.989, test=0.926) total time=12.5min
# [CV 5/10; 609/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 609/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 2/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 2/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 8/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 6/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 6/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.601) total time=11.2min
# [CV 10/10; 606/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 607/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 2/10; 607/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 607/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 607/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 9/10; 607/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 9/10; 607/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 3/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 3/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 8/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 8/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 609/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 609/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   4.9s
# [CV 8/10; 609/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 8/10; 609/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 1/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 1/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 7/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 5/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 10/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.619) total time=11.2min
# [CV 2/10; 627/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 627/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 1/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 1/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 10/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 629/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 629/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 10/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 1/10; 632/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 3/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 8/10; 634/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 634/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 3/10; 636/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 636/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.936) total time=10.2min
# [CV 9/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 5/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 3/10; 634/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 3/10; 634/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   4.7s
# [CV 2/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 9/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 9/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 9/10; 636/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 636/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 10/10; 637/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 10/10; 637/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 8/10; 638/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 8/10; 638/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.622) total time=10.4min
# [CV 1/10; 565/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 5/10; 565/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 565/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 8/10; 565/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 565/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 2/10; 566/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 566/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 5/10; 566/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 566/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 9/10; 566/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 9/10; 566/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 3/10; 567/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 567/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 10/10; 567/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 567/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 5/10; 568/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 568/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 7/10; 568/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 568/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 1/10; 569/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 569/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.987, test=0.887) total time=11.1min
# [CV 7/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 7/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 631/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 631/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 632/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 632/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 634/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 634/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 6/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 6/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 636/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 636/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 5/10; 637/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 637/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.629) total time=10.6min
# [CV 7/10; 547/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 547/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.991, test=0.633) total time=12.7min
# [CV 8/10; 616/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 616/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 8/10; 617/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 8/10; 617/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 10/10; 618/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 618/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 2/10; 620/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 620/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 3/10; 621/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 621/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 622/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 622/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.844) total time=12.2min
# [CV 5/10; 614/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 614/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 615/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 615/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 9/10; 615/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 615/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 616/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 6/10; 616/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 617/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 6/10; 617/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 3/10; 619/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 3/10; 619/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 620/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 4/10; 620/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 621/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 621/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 6/10; 622/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 6/10; 622/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.593) total time=12.2min
