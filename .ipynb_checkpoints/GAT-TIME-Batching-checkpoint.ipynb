# %% [markdown]
# ## GAT

# %%
from dataAnalysis.DataAnalysis import DataAnalysis
import pandas as pd
import cudf

data = pd.read_csv(r"extdata/sbcdata.csv", header=0)
data_analysis = DataAnalysis(data)
# Out:
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Training:
# Assessable data are 528101 cases and 1015074 CBCs
# Control data are 527038 cases and 1013548 CBCs
# Sepsis data are 1488 cases and 1526 CBCs
# $$$$$$$$$$$$$$$$$$$$
# Testing:
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 365794, Sepsis: 490
# Assessable data are 180494 cases and 366284 CBCs
# Control data are 180157 cases and 365794 CBCs
# Sepsis data are 472 cases and 490 CBCs
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 437629, Sepsis: 448
# Assessable data are 157922 cases and 438077 CBCs
# Control data are 180157 cases and 437629 CBCs
# Sepsis data are 438 cases and 448 CBCs

# %%
data = pd.concat((data_analysis.get_training_data(), data_analysis.get_testing_data()))
data = cudf.from_pandas(data)

# %%
data = data.sort_values("Id")

# %%
unique_ids = data["Id"].unique()

# %%
data = data.reset_index(drop=True)

# %%
data.pop("index")
# Out:
# 0           665587
# 1           665588
# 2           665589
# 3           665590
# 4           665592
#             ...
# 1381353    2709535
# 1381354    2709538
# 1381355    2709541
# 1381356    2709539
# 1381357    2709540
# Name: index, Length: 1381358, dtype: int64

# %%
data
# Out:
#              Id  Age Sex Diagnosis   Center         Set Sender  Episode  \
# 0             1   79   M   Control  Leipzig    Training     ED        1
# 1             2   35   M   Control  Leipzig    Training    GEN        1
# 2             3   47   W   Control  Leipzig    Training    AMB        1
# 3             4   28   M   Control  Leipzig    Training     ED        1
# 4             5   63   W   Control  Leipzig    Training    GEN        1
# ...         ...  ...  ..       ...      ...         ...    ...      ...
# 1381353  778980   56   M    Sepsis  Leipzig  Validation    GEN        1
# 1381354  778980   56   M    Sepsis  Leipzig  Validation    GEN        1
# 1381355  778980   56   M    Sepsis  Leipzig  Validation    GEN        1
# 1381356  778980   56   M    Sepsis  Leipzig  Validation    GEN        1
# 1381357  778980   56   M    Sepsis  Leipzig  Validation    GEN        1
#
#              Time TargetIcu  SecToIcu    CRP   HGB   MCV   PCT    PLT   RBC  \
# 0           420.0      <NA>      <NA>   0.75   8.1  86.0  <NA>  167.0  4.36
# 1             0.0      <NA>      <NA>   <NA>  10.6  79.9  <NA>  199.0  6.02
# 2             0.0      <NA>      <NA>   3.87   8.7  89.9  <NA>  298.0  4.37
# 3           780.0      <NA>      <NA>   0.52   9.9  96.2  <NA>  216.0  4.79
# 4        540060.0      <NA>      <NA>  13.32   6.5  90.2  <NA>  349.0  3.56
# ...           ...       ...       ...    ...   ...   ...   ...    ...   ...
# 1381353       0.0      MICU  902760.0  27.81   7.1  98.2  <NA>  158.0  3.28
# 1381354  606720.0      MICU  296040.0  17.88   6.7  96.6  <NA>  121.0  3.20
# 1381355  895680.0      MICU    7080.0  22.98   7.7  91.8  <NA>  155.0  3.67
# 1381356  870420.0      MICU   32340.0  20.46   6.5  93.2  <NA>  114.0  3.07
# 1381357  888540.0      MICU   14220.0  19.26   6.6  91.1  <NA>  149.0  3.14
#
#          WBC    Label
# 0        7.3  Control
# 1        4.7  Control
# 2        7.1  Control
# 3        5.3  Control
# 4        7.1  Control
# ...      ...      ...
# 1381353  9.4  Control
# 1381354  7.2  Control
# 1381355  7.1   Sepsis
# 1381356  8.3  Control
# 1381357  6.5   Sepsis
#
# [1381358 rows x 19 columns]

# %%
from dataAnalysis.Constants import SEX_CATEGORY_COLUMN_NAME, SEX_COLUMN_NAME, FEATURES
data[SEX_CATEGORY_COLUMN_NAME] = data.loc[:, SEX_COLUMN_NAME] =="W"

# %%
data[SEX_CATEGORY_COLUMN_NAME] = data[SEX_CATEGORY_COLUMN_NAME].astype("int8")
data["Label"] = data["Label"] == "Sepsis"
data["Label"] = data["Label"].astype("int8")

# %%
import numpy as np
import matplotlib.pyplot as plt

def getPositionEncoding(seq_len, d = len(FEATURES), n=10000):
    P = np.zeros((seq_len, d))
    for k in range(seq_len):
        for i in np.arange(int(d/2)):
            denominator = np.power(n, 2*i/d)
            P[k, 2*i] = np.sin(k/denominator)
            P[k, 2*i+1] = np.cos(k/denominator)
    return P

# %%
from dataAnalysis.Constants import FEATURES
for feature in FEATURES:
    data[feature] = (data[feature] - data[feature].mean()) / data[feature].std()

# %%
np.random.seed(42)
random = np.random.uniform(0, 1 ,data.shape[0])
data["random"] = random

# %%
import numpy as np
import cupy as cp
import time
from torch_geometric.data import Data
import torch

graph_list = []
start = time.time()
i = 0
for Id, group in data.groupby("Id"):
    i+=1
    if i % 1000 == 0:
        print(f"{str(i / unique_ids.shape[0] * 100)} %")

print(time.time() - start)
# Out:
# 0.1411243375976404 %
# 0.2822486751952808 %
# 0.4233730127929212 %
# 0.5644973503905616 %
# 0.705621687988202 %
# 0.8467460255858424 %
# 0.9878703631834829 %
# 1.1289947007811232 %
# 1.2701190383787637 %
# 1.411243375976404 %
# 1.5523677135740444 %
# 1.6934920511716849 %
# 1.8346163887693252 %
# 1.9757407263669657 %
# 2.116865063964606 %
# 2.2579894015622464 %
# 2.399113739159887 %
# 2.5402380767575274 %
# 2.6813624143551675 %
# 2.822486751952808 %
# 2.963611089550448 %
# 3.1047354271480887 %
# 3.2458597647457297 %
# 3.3869841023433698 %
# 3.52810843994101 %
# 3.6692327775386504 %
# 3.810357115136291 %
# 3.9514814527339315 %
# 4.092605790331572 %
# 4.233730127929212 %
# 4.374854465526853 %
# 4.515978803124493 %
# 4.657103140722133 %
# 4.798227478319774 %
# 4.939351815917414 %
# 5.080476153515055 %
# 5.221600491112695 %
# 5.362724828710335 %
# 5.503849166307976 %
# 5.644973503905616 %
# 5.786097841503256 %
# 5.927222179100896 %
# 6.068346516698537 %
# 6.209470854296177 %
# 6.350595191893818 %
# 6.491719529491459 %
# 6.632843867089099 %
# 6.7739682046867395 %
# 6.915092542284379 %
# 7.05621687988202 %
# 7.197341217479661 %
# 7.338465555077301 %
# 7.479589892674941 %
# 7.620714230272582 %
# 7.761838567870222 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 10
#       8 start = time.time()
#       9 i = 0
# ---> 10 for Id, group in data.groupby("Id"):
#      11     i+=1
#      12     if i % 1000 == 0:
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/groupby/groupby.py:287, in GroupBy.__iter__(self)
#     285     group_names = group_names.to_pandas()
#     286 for i, name in enumerate(group_names):
# --> 287     yield name, grouped_values[offsets[i] : offsets[i + 1]]
#
# File ~/.local/lib/python3.10/site-packages/nvtx/nvtx.py:101, in annotate.__call__.<locals>.inner(*args, **kwargs)
#      98 @wraps(func)
#      99 def inner(*args, **kwargs):
#     100     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101     result = func(*args, **kwargs)
#     102     libnvtx_pop_range(self.domain.handle)
#     103     return result
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/dataframe.py:1163, in DataFrame.__getitem__(self, arg)
#    1160     return self._get_columns_by_label(arg, downcast=True)
#    1162 elif isinstance(arg, slice):
# -> 1163     return self._slice(arg)
#    1165 elif can_convert_to_column(arg):
#    1166     mask = arg
#
# File ~/.local/lib/python3.10/site-packages/nvtx/nvtx.py:101, in annotate.__call__.<locals>.inner(*args, **kwargs)
#      98 @wraps(func)
#      99 def inner(*args, **kwargs):
#     100     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101     result = func(*args, **kwargs)
#     102     libnvtx_pop_range(self.domain.handle)
#     103     return result
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/dataframe.py:1398, in DataFrame._slice(self, arg)
#    1387     return self._gather(
#    1388         cudf.core.column.arange(
#    1389             start, stop=stop, step=stride, dtype=np.int32
#    1390         )
#    1391     )
#    1393 columns_to_slice = [
#    1394     *(self._index._data.columns if not is_range_index else []),
#    1395     *self._columns,
#    1396 ]
#    1397 result = self._from_columns_like_self(
# -> 1398     libcudf.copying.columns_slice(columns_to_slice, [start, stop])[0],
#    1399     self._column_names,
#    1400     None if is_range_index else self._index.names,
#    1401 )
#    1403 if is_range_index:
#    1404     result.index = self.index[start:stop]
#
# File /usr/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File copying.pyx:379, in cudf._lib.copying.columns_slice()
#
# File utils.pyx:327, in cudf._lib.utils.columns_from_table_view()
#
# File column.pyx:634, in cudf._lib.column.Column.from_column_view()
#
# File column.pyx:641, in cudf._lib.column.Column.from_column_view()
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:1522, in build_column(data, dtype, size, mask, offset, null_count, children)
#    1520 if _is_non_decimal_numeric_dtype(dtype):
#    1521     assert data is not None
# -> 1522     return cudf.core.column.NumericalColumn(
#    1523         data=data,
#    1524         dtype=dtype,
#    1525         mask=mask,
#    1526         size=size,
#    1527         offset=offset,
#    1528         null_count=null_count,
#    1529     )
#    1530 if is_categorical_dtype(dtype):
#    1531     if not len(children) == 1:
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/numerical.py:96, in NumericalColumn.__init__(self, data, dtype, mask, size, offset, null_count)
#      94     size = (data.size // dtype.itemsize) - offset
#      95 self._nan_count = None
# ---> 96 super().__init__(
#      97     data,
#      98     size=size,
#      99     dtype=dtype,
#     100     mask=mask,
#     101     offset=offset,
#     102     null_count=null_count,
#     103 )
#
# File column.pyx:74, in cudf._lib.column.Column.__init__()
#
# File column.pyx:177, in cudf._lib.column.Column.set_base_mask()
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/numerical.py:105, in NumericalColumn._clear_cache(self)
#      95     self._nan_count = None
#      96     super().__init__(
#      97         data,
#      98         size=size,
#    (...)
#     102         null_count=null_count,
#     103     )
# --> 105 def _clear_cache(self):
#     106     super()._clear_cache()
#     107     self._nan_count = None
#
# KeyboardInterrupt:

# %%
import threading
class Fred(threading.Thread):
    def __init__(self, Id, it):
        threading.Thread.__init__(self)
        self.id = Id
        self.it = it
    
    def run(self):
        self.id
        self.it = self.it+1
        

import numpy as np
import cupy as cp
import time
from torch_geometric.data import Data
import torch

graph_list = []
start = time.time()
i = 0
for Id, group in data.groupby("Id"):
    fred = Fred(Id, i)
    fred.start()
    i = fred.it
    if i % 1000 == 0:
        print(f"{str(i / unique_ids.shape[0] * 100)} %")

print(time.time() - start)
# Out:
# 0.1411243375976404 %
# 0.2822486751952808 %
# 0.4233730127929212 %
# 0.5644973503905616 %
# 0.705621687988202 %
# 0.8467460255858424 %
# 0.9878703631834829 %
# 1.1289947007811232 %
# 1.2701190383787637 %
# 1.411243375976404 %
# 1.5523677135740444 %
# 1.6934920511716849 %
# 1.8346163887693252 %
# 1.9757407263669657 %
# 2.116865063964606 %
# 2.2579894015622464 %
# 2.399113739159887 %
# 2.5402380767575274 %
# 2.6813624143551675 %
# 2.822486751952808 %
# 2.963611089550448 %
# 3.1047354271480887 %
# 3.2458597647457297 %
# 3.3869841023433698 %
# 3.52810843994101 %
# 3.6692327775386504 %
# 3.810357115136291 %
# 3.9514814527339315 %
# 4.092605790331572 %
# 4.233730127929212 %
# 4.374854465526853 %
# 4.515978803124493 %
# 4.657103140722133 %
# 4.798227478319774 %
# 4.939351815917414 %
# 5.080476153515055 %
# 5.221600491112695 %
# 5.362724828710335 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 22
#      20 start = time.time()
#      21 i = 0
# ---> 22 for Id, group in data.groupby("Id"):
#      23     fred = Fred(Id, i)
#      24     fred.start()
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/groupby/groupby.py:287, in GroupBy.__iter__(self)
#     285     group_names = group_names.to_pandas()
#     286 for i, name in enumerate(group_names):
# --> 287     yield name, grouped_values[offsets[i] : offsets[i + 1]]
#
# File ~/.local/lib/python3.10/site-packages/nvtx/nvtx.py:101, in annotate.__call__.<locals>.inner(*args, **kwargs)
#      98 @wraps(func)
#      99 def inner(*args, **kwargs):
#     100     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101     result = func(*args, **kwargs)
#     102     libnvtx_pop_range(self.domain.handle)
#     103     return result
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/dataframe.py:1163, in DataFrame.__getitem__(self, arg)
#    1160     return self._get_columns_by_label(arg, downcast=True)
#    1162 elif isinstance(arg, slice):
# -> 1163     return self._slice(arg)
#    1165 elif can_convert_to_column(arg):
#    1166     mask = arg
#
# File ~/.local/lib/python3.10/site-packages/nvtx/nvtx.py:101, in annotate.__call__.<locals>.inner(*args, **kwargs)
#      98 @wraps(func)
#      99 def inner(*args, **kwargs):
#     100     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101     result = func(*args, **kwargs)
#     102     libnvtx_pop_range(self.domain.handle)
#     103     return result
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/dataframe.py:1398, in DataFrame._slice(self, arg)
#    1387     return self._gather(
#    1388         cudf.core.column.arange(
#    1389             start, stop=stop, step=stride, dtype=np.int32
#    1390         )
#    1391     )
#    1393 columns_to_slice = [
#    1394     *(self._index._data.columns if not is_range_index else []),
#    1395     *self._columns,
#    1396 ]
#    1397 result = self._from_columns_like_self(
# -> 1398     libcudf.copying.columns_slice(columns_to_slice, [start, stop])[0],
#    1399     self._column_names,
#    1400     None if is_range_index else self._index.names,
#    1401 )
#    1403 if is_range_index:
#    1404     result.index = self.index[start:stop]
#
# File /usr/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File copying.pyx:379, in cudf._lib.copying.columns_slice()
#
# File utils.pyx:327, in cudf._lib.utils.columns_from_table_view()
#
# File column.pyx:641, in cudf._lib.column.Column.from_column_view()
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:1522, in build_column(data, dtype, size, mask, offset, null_count, children)
#    1520 if _is_non_decimal_numeric_dtype(dtype):
#    1521     assert data is not None
# -> 1522     return cudf.core.column.NumericalColumn(
#    1523         data=data,
#    1524         dtype=dtype,
#    1525         mask=mask,
#    1526         size=size,
#    1527         offset=offset,
#    1528         null_count=null_count,
#    1529     )
#    1530 if is_categorical_dtype(dtype):
#    1531     if not len(children) == 1:
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/numerical.py:80, in NumericalColumn.__init__(self, data, dtype, mask, size, offset, null_count)
#      77 _nan_count: Optional[int]
#      78 _VALID_BINARY_OPERATIONS = BinaryOperand._SUPPORTED_BINARY_OPERATIONS
# ---> 80 def __init__(
#      81     self,
#      82     data: Buffer,
#      83     dtype: DtypeObj,
#      84     mask: Optional[Buffer] = None,
#      85     size: Optional[int] = None,  # TODO: make this non-optional
#      86     offset: int = 0,
#      87     null_count: Optional[int] = None,
#      88 ):
#      89     dtype = cudf.dtype(dtype)
#      91     if data.size % dtype.itemsize:
#
# KeyboardInterrupt:

# %%
import numpy as np
import cupy as cp
import time
from torch_geometric.data import Data
import torch
import threading

class Edgy_Fred(threading.Thread):
    def __init__(self, indices):
        threading.Thread.__init__(self)
        self.indices = indices
        self.edge_index = None
    
    def run(self):
        indices = cp.expand_dims(self.indices.values, axis = 1)
        target = cp.repeat(indices, indices.shape[0], axis = 1)
        source = target.transpose().flatten()
        target = target.flatten()
        self.edge_index = np.asarray([np.asarray(source.get()), np.asarray(target.get())])
        
        
class Encoding_Fred(threading.Thread):
    def __init__(self, group):
        threading.Thread.__init__(self)
        self.group = group
        self.encoding = None
    
    def run(self):
        self.encoding = getPositionEncoding(self.group.shape[0])
        
class Masked_Fred(threading.Thread):
    def __init__(self, group):
        threading.Thread.__init__(self)
        self.group = group
        self.train_mask = None
        self.val_mask = None
        self.test_mask = None
    
    def run(self):
        train_mask_ser = (self.group["Set"] != "Validation").to_arrow().to_pylist()
        val_ratio_mask = (self.group["random"] >= 0.8)
        train_ratio_mask = (self.group["random"] < 0.8)
        self.val_mask = np.logical_and(train_mask_ser, val_ratio_mask.to_arrow().to_pylist())
        self.train_mask = np.logical_and(train_mask_ser, train_ratio_mask.to_arrow().to_pylist())    
        self.test_mask = (group["Set"] == "Validation").values.get()
        

graph_list = []
start = time.time()
i = 0
for Id, group in data.groupby("Id"):
    group = group.reset_index().sort_values("Time").reset_index()
    indices = group.index

    ## Edge construction
    edgy_fred = Edgy_Fred(indices)
    edgy_fred.start()

    ## Features
    X_features = torch.tensor(group[FEATURES].values.get()).type(torch.float32)


    ## Positions
    encoding_fred = Encoding_Fred(group)
    encoding_fred.start()

    ## Masks
    masked_fred = Masked_Fred(group)
    masked_fred.start()
    
    ## Graph
    graph = Data(x= X_features + encoding_fred.encoding,
                 y= torch.tensor(group["Label"].values.get()).type(torch.int8),
                 edge_index= torch.tensor(edgy_fred.edge_index),
                 train_mask=torch.from_numpy(masked_fred.train_mask).type(torch.bool),
                 test_mask=torch.from_numpy(masked_fred.test_mask).type(torch.bool),
                 val_mask=torch.from_numpy(masked_fred.val_mask).type(torch.bool))
    graph_list.append(graph)
    i+=1
    if i % 1000 == 0:
        print(f"{str(i / unique_ids.shape[0] * 100)} %")

print(time.time() - start )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[26], line 64
#      60 X_features = torch.tensor(group[FEATURES].values.get()).type(torch.float32)
#      63 ## Positions
# ---> 64 encoding_fred = Encoding_Fred(group)
#      65 encoding_fred.start()
#      67 ## Masks
#
# Cell In[26], line 24, in Encoding_Fred.__init__(self, indices)
#      23 def __init__(self, indices):
# ---> 24     threading.Thread.__init__(self, group)
#      25     self.group = group
#      26     self.encoding = None
#
# File /usr/lib/python3.10/threading.py:850, in Thread.__init__(self, group, target, name, args, kwargs, daemon)
#     827 def __init__(self, group=None, target=None, name=None,
#     828              args=(), kwargs=None, *, daemon=None):
#     829     """This constructor should always be called with keyword arguments. Arguments are:
#     830
#     831     *group* should be None; reserved for future extension when a ThreadGroup
#    (...)
#     848
#     849     """
# --> 850     assert group is None, "group argument must be None for now"
#     851     if kwargs is None:
#     852         kwargs = {}
#
# AssertionError: group argument must be None for now

# %%
device = torch.device("cpu") #torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")

WEIGHT = torch.tensor([664])
WEIGHT = WEIGHT.to(device)

print("Data shifted to the device " + str(device))
# Out:
# Data shifted to the device cpu

# %%
import torch.nn.functional as F
from torch_geometric.nn import GATConv, GCNConv,GATv2Conv, GINConv, global_add_pool
from torch.nn import Linear
import torch
from dataAnalysis.Constants import FEATURES
from torch.nn import Linear, ReLU, Sequential
from torch.nn import BatchNorm1d as BatchNorm

class GraphNeuralNetwork(torch.nn.Module):
    def __init__(self, hidden_dim = 128, out_channels = 1):
        super(GraphNeuralNetwork, self).__init__()
        input_dim = len(FEATURES)      
        
        conv_1= GATConv(input_dim, hidden_dim,heads=2, add_self_loops = False)
        conv_end = GATConv((-1,-1), out_channels,add_self_loops = False)
        
        self.conv_1 = conv_1
        self.conv_end = conv_end
        

    def forward(self, graph):
        x, edge_index = graph.x, graph.edge_index
        x = x.type(torch.float)
        x = self.conv_1(x, edge_index)
        x = F.normalize(x, p=2., dim=-1)
        x = torch.relu(x)
        x = self.conv_end(x, edge_index)
        return x
            
    def predict_proba(self, graph, mask):
        with torch.inference_mode():
            self.eval()
            logits = self.forward(graph)
            scores = torch.sigmoid(torch.squeeze(logits[mask]))
            scores = torch.unsqueeze(scores, 0)
            proba_predict = torch.concat((1- scores, scores), dim = 0)
            return torch.transpose(proba_predict, 0, 1)
            
    def predict(self, graph, mask):
        return torch.round(self.predict_proba(graph, mask)[:, 1])

# %%
import os.path as osp

import torch
from torch_geometric.data import Dataset, download_url
import os

class TimeSbc(Dataset):
    def __init__(self, root, transform=None, pre_transform=None, pre_filter=None):
        super().__init__(root, transform, pre_transform, pre_filter)

    @property
    def raw_file_names(self):
        return "extdata/sbcdata.csv"

    @property
    def processed_file_names(self):
        return [f"gat_batch/data_{i}.pt" for i in unique_ids.to_arrow()]

    def download(self):
        pass

    def process(self):
        idx = 0
        for graph in graph_list:
            torch.save(data, osp.join("gat_batch", f'data_{idx}.pt'))
            idx += 1

    def len(self):
        return len(self.processed_file_names)

    def get(self, idx):
        data = torch.load(osp.join("gat_batch", f'data_{idx}.pt'))
        return data
    
    def get_data_list(self):
        data_list = []
        for file in os.listdir("gat_batch"):
            data = torch.load(osp.join("gat_batch", file))
            data_list.append(data)
        return data_list

# %%
time_sbc = TimeSbc("")
time_sbc.process()
# Out:
# Processing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 time_sbc = TimeSbc("")
#       2 time_sbc.process()
#
# Cell In[20], line 9, in TimeSbc.__init__(self, root, transform, pre_transform, pre_filter)
#       8 def __init__(self, root, transform=None, pre_transform=None, pre_filter=None):
# ----> 9     super().__init__(root, transform, pre_transform, pre_filter)
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/dataset.py:97, in Dataset.__init__(self, root, transform, pre_transform, pre_filter, log)
#      94     self._download()
#      96 if self.has_process:
# ---> 97     self._process()
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/dataset.py:230, in Dataset._process(self)
#     227     print('Processing...', file=sys.stderr)
#     229 makedirs(self.processed_dir)
# --> 230 self.process()
#     232 path = osp.join(self.processed_dir, 'pre_transform.pt')
#     233 torch.save(_repr(self.pre_transform), path)
#
# Cell In[20], line 25, in TimeSbc.process(self)
#      23 idx = 0
#      24 for graph in graph_list:
# ---> 25     torch.save(data, osp.join("gat_batch", f'data_{idx}.pt'))
#      26     idx += 1
#
# File /usr/local/lib/python3.10/dist-packages/torch/serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     439 if _use_new_zipfile_serialization:
#     440     with _open_zipfile_writer(f) as opened_zipfile:
# --> 441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#     443 else:
#
# File /usr/local/lib/python3.10/dist-packages/torch/serialization.py:653, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     651 pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     652 pickler.persistent_id = persistent_id
# --> 653 pickler.dump(obj)
#     654 data_value = data_buf.getvalue()
#     655 zip_file.write_record('data.pkl', data_value, len(data_value))
#
# File /usr/local/lib/python3.10/dist-packages/torch/serialization.py:602, in _save.<locals>.persistent_id(obj)
#     596 # Since loading storages that view the same data with different dtypes is
#     597 # not supported, we need to keep track of the dtype associated with each
#     598 # storage data_ptr and throw an error if the dtype is ever different.
#     599 # TODO: This feature could be added in the future
#     600 storage_dtypes: Dict[int, torch.dtype] = {}
# --> 602 def persistent_id(obj):
#     603     # FIXME: the docs say that persistent_id should only return a string
#     604     # but torch store returns tuples. This works only in the binary protocol
#     605     # see
#     606     # https://docs.python.org/2/library/pickle.html#pickling-and-unpickling-external-objects
#     607     # https://github.com/python/cpython/blob/master/Lib/pickle.py#L527-L537
#     608     if isinstance(obj, torch.storage.TypedStorage) or torch.is_storage(obj):
#     610         if isinstance(obj, torch.storage.TypedStorage):
#     611             # TODO: Once we decide to break serialization FC, this case
#     612             # can be deleted
#
# KeyboardInterrupt:

# %%
len([graph.cpu() for graph in graph_list])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 len([graph.cpu() for graph in graph_list])
#
# Cell In[50], line 1, in <listcomp>(.0)
# ----> 1 len([graph.cpu() for graph in graph_list])
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py:268, in BaseData.cpu(self, *args)
#     265 def cpu(self, *args: List[str]):
#     266     r"""Copies attributes to CPU memory, either for all attributes or only
#     267     the ones given in :obj:`*args`."""
# --> 268     return self.apply(lambda x: x.cpu(), *args)
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py:245, in BaseData.apply(self, func, *args)
#     242 r"""Applies the function :obj:`func`, either to all attributes or only
#     243 the ones given in :obj:`*args`."""
#     244 for store in self.stores:
# --> 245     store.apply(func, *args)
#     246 return self
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/storage.py:183, in BaseStorage.apply(self, func, *args)
#     180 r"""Applies the function :obj:`func`, either to all attributes or only
#     181 the ones given in :obj:`*args`."""
#     182 for key, value in self.items(*args):
# --> 183     self[key] = recursive_apply(value, func)
#     184 return self
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/storage.py:679, in recursive_apply(data, func)
#     677 def recursive_apply(data: Any, func: Callable) -> Any:
#     678     if isinstance(data, Tensor):
# --> 679         return func(data)
#     680     elif isinstance(data, torch.nn.utils.rnn.PackedSequence):
#     681         return func(data)
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py:268, in BaseData.cpu.<locals>.<lambda>(x)
#     265 def cpu(self, *args: List[str]):
#     266     r"""Copies attributes to CPU memory, either for all attributes or only
#     267     the ones given in :obj:`*args`."""
# --> 268     return self.apply(lambda x: x.cpu(), *args)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
graph_list_on_device = [graph.cpu() for graph in graph_list]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 graph_list_on_device = [graph.cpu() for graph in graph_list]
#
# Cell In[47], line 1, in <listcomp>(.0)
# ----> 1 graph_list_on_device = [graph.cpu() for graph in graph_list]
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py:268, in BaseData.cpu(self, *args)
#     265 def cpu(self, *args: List[str]):
#     266     r"""Copies attributes to CPU memory, either for all attributes or only
#     267     the ones given in :obj:`*args`."""
# --> 268     return self.apply(lambda x: x.cpu(), *args)
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py:245, in BaseData.apply(self, func, *args)
#     242 r"""Applies the function :obj:`func`, either to all attributes or only
#     243 the ones given in :obj:`*args`."""
#     244 for store in self.stores:
# --> 245     store.apply(func, *args)
#     246 return self
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/storage.py:183, in BaseStorage.apply(self, func, *args)
#     180 r"""Applies the function :obj:`func`, either to all attributes or only
#     181 the ones given in :obj:`*args`."""
#     182 for key, value in self.items(*args):
# --> 183     self[key] = recursive_apply(value, func)
#     184 return self
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/storage.py:679, in recursive_apply(data, func)
#     677 def recursive_apply(data: Any, func: Callable) -> Any:
#     678     if isinstance(data, Tensor):
# --> 679         return func(data)
#     680     elif isinstance(data, torch.nn.utils.rnn.PackedSequence):
#     681         return func(data)
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/data/data.py:268, in BaseData.cpu.<locals>.<lambda>(x)
#     265 def cpu(self, *args: List[str]):
#     266     r"""Copies attributes to CPU memory, either for all attributes or only
#     267     the ones given in :obj:`*args`."""
# --> 268     return self.apply(lambda x: x.cpu(), *args)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
from torch_geometric.loader import DataLoader

data_loader = DataLoader(graph_list_on_device, batch_size=32)

# %%
import torch 

class ModelWrapper():
    def __init__(self, data_loader):
        self.LEARNING_RATE = 3e-4
        self.MAX_EPOCHS = 40000

        self.model = GraphNeuralNetwork(hidden_dim = 128, out_channels=1) 
        self.model = self.model.to(device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.LEARNING_RATE,betas=(0.9, 0.999), eps=1e-08)
        self.data_loader = data_loader
        
        self.last_loss = 0
        self.increased_loss = 0
        self.BREAKING_THRESHOLD = 10    
        self.val_loss = []
        self.train_loss = []
    
    def validate(self):
        with torch.inference_mode():
            for data in self.data_loader:
                self.model.eval()
                out = self.model(data)
                loss = F.binary_cross_entropy_with_logits(torch.squeeze(out[data.val_mask]), data.y[data.val_mask].type(torch.float32),
                                                          pos_weight=WEIGHT)
                self.val_loss.append(loss.item())
                if loss.item() > self.last_loss:
                    self.increased_loss += 1
                else:
                    self.increased_loss = 0
                self.last_loss = loss.item()

    def train(self):
        for epoch in range(self.MAX_EPOCHS):
            for data in self.data_loader:
                self.model.train()
                self.optimizer.zero_grad()
                out = self.model(data)
                loss = F.binary_cross_entropy_with_logits(torch.squeeze(out[data.train_mask]), data.y[data.train_mask].type(torch.float32),
                                                          pos_weight=WEIGHT)
                self.train_loss.append(loss.item())
                loss.backward()
                self.optimizer.step()
                self.validate() 

                if self.increased_loss >= self.BREAKING_THRESHOLD:
    #                 print(f"Breaked at {str(epoch)}")
                    break
            
    def get_model(self):
        return self.model    
    
    def plot_loss(self):
        plt.plot(self.epochs, self.train_loss, 'g', label='Training loss')
        plt.plot(self.epochs, self.val_loss, 'y', label='Validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()

# %%
model_wrapper = ModelWrapper(data_loader)
model_wrapper.train()
# Out:
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [2,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [1,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[42], line 2
#       1 model_wrapper = ModelWrapper(data_loader)
# ----> 2 model_wrapper.train()
#
# Cell In[41], line 38, in ModelWrapper.train(self)
#      36 self.model.train()
#      37 self.optimizer.zero_grad()
# ---> 38 out = self.model(data)
#      39 loss = F.binary_cross_entropy_with_logits(torch.squeeze(out[data.train_mask]), data.y[data.train_mask].type(torch.float32),
#      40                                           pos_weight=WEIGHT)
#      41 self.train_loss.append(loss.item())
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[32], line 27, in GraphNeuralNetwork.forward(self, graph)
#      25 x = F.normalize(x, p=2., dim=-1)
#      26 x = torch.relu(x)
# ---> 27 x = self.conv_end(x, edge_index)
#      28 return x
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/nn/conv/gat_conv.py:252, in GATConv.forward(self, x, edge_index, edge_attr, size, return_attention_weights)
#     246             raise NotImplementedError(
#     247                 "The usage of 'edge_attr' and 'add_self_loops' "
#     248                 "simultaneously is currently not yet supported for "
#     249                 "'edge_index' in a 'SparseTensor' form")
#     251 # edge_updater_type: (alpha: OptPairTensor, edge_attr: OptTensor)
# --> 252 alpha = self.edge_updater(edge_index, alpha=alpha, edge_attr=edge_attr)
#     254 # propagate_type: (x: OptPairTensor, alpha: Tensor)
#     255 out = self.propagate(edge_index, x=x, alpha=alpha, size=size)
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/nn/conv/message_passing.py:531, in MessagePassing.edge_updater(self, edge_index, **kwargs)
#     527 coll_dict = self._collect(self._edge_user_args, edge_index, size,
#     528                           kwargs)
#     530 edge_kwargs = self.inspector.distribute('edge_update', coll_dict)
# --> 531 out = self.edge_update(**edge_kwargs)
#     533 for hook in self._edge_update_forward_hooks.values():
#     534     res = hook(self, (edge_index, kwargs), out)
#
# File /usr/local/lib/python3.10/dist-packages/torch_geometric/nn/conv/gat_conv.py:294, in GATConv.edge_update(self, alpha_j, alpha_i, edge_attr, index, ptr, size_i)
#     291     alpha_edge = (edge_attr * self.att_edge).sum(dim=-1)
#     292     alpha = alpha + alpha_edge
# --> 294 alpha = F.leaky_relu(alpha, self.negative_slope)
#     295 alpha = softmax(alpha, index, ptr, size_i)
#     296 alpha = F.dropout(alpha, p=self.dropout, training=self.training)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:1632, in leaky_relu(input, negative_slope, inplace)
#    1630     result = torch._C._nn.leaky_relu_(input, negative_slope)
#    1631 else:
# -> 1632     result = torch._C._nn.leaky_relu(input, negative_slope)
#    1633 return result
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
model = model_wrapper.get_model()
graph = graph.cpu()
model = model.cpu()

# %%
y_dict = Evaluation.create_y_dict(model.predict(graph, test_mask), model.predict_proba(graph, test_mask) , graph.y[test_mask])

# %%
from dataAnalysis.Metrics import Evaluation

Evaluation.plot_confusion_matrix_from_pred(model.predict(graph, test_mask), graph.y[test_mask])
Evaluation.get_df_metrics_from_pred(y_dict, y_dict)

# %%
from IPython.display import Audio
sound_file = './finish_sound.mp3'
Audio(sound_file, autoplay=True)

# %%
import time

for i in range(10000):
    time.sleep(60)
    print("Sleeping")
# Out:
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
