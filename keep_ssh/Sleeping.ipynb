# %%
import time

for i in range(10000*100):
    time.sleep(60)
    print("Sleeping")
# Out:
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# Sleeping
# ...
