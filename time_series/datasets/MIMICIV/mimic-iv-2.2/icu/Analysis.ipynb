# %% [markdown]
# ## Constants

# %%
CAREGIVER_CSV = "caregiver.csv"
CHART_EVENT_CSV= "chartevents.csv"
D_ITEMS_CSV = "d_items.csv"
DATE_TIME_EVENTS_CSV = "datetimeevents.csv"
ICU_STAYS_CSV = "icustays.csv"
INGREDIENT_EVENTS_CSV = "ingredientevents.csv"
INPUT_EVENTS_CSV = "inputevents.csv"
OUTPUT_EVENTS_CSV = "outputevents.csv"
PROCEDURE_EVENTS_CSV = "procedureevents.csv"

# %%
import pandas as pd

caregiver_df = pd.read_csv(CAREGIVER_CSV)
icu_stays_df = pd.read_csv(ICU_STAYS_CSV)

# %%
icu_stays_df.head()
# Out:
#    subject_id   hadm_id   stay_id  \
# 0    10000032  29079034  39553978
# 1    10000980  26913865  39765666
# 2    10001217  24597018  37067082
# 3    10001217  27703517  34592300
# 4    10001725  25563031  31205490
#
#                                      first_careunit  \
# 0                Medical Intensive Care Unit (MICU)
# 1                Medical Intensive Care Unit (MICU)
# 2               Surgical Intensive Care Unit (SICU)
# 3               Surgical Intensive Care Unit (SICU)
# 4  Medical/Surgical Intensive Care Unit (MICU/SICU)
#
#                                       last_careunit               intime  \
# 0                Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 2               Surgical Intensive Care Unit (SICU)  2157-11-20 19:18:02
# 3               Surgical Intensive Care Unit (SICU)  2157-12-19 15:42:24
# ...

# %%
date_time_events_df = pd.read_csv(DATE_TIME_EVENTS_CSV)

# %%
date_time_events_df.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10000032  29079034  39553978         66056  2180-07-23 21:02:00
# 1    10000032  29079034  39553978         66056  2180-07-23 21:02:00
# 2    10000032  29079034  39553978         88981  2180-07-23 14:24:00
# 3    10000032  29079034  39553978         88981  2180-07-23 14:24:00
# 4    10000980  26913865  39765666         36518  2189-06-27 09:13:00
#
#              storetime  itemid                value valueuom  warning
# 0  2180-07-23 21:02:00  225754  2180-07-23 00:00:00     Date        0
# 1  2180-07-23 21:02:00  225755  2180-07-23 00:00:00     Date        0
# 2  2180-07-23 14:24:00  225754  2180-07-23 14:24:00     Date        0
# 3  2180-07-23 14:24:00  225755  2180-07-23 14:24:00     Date        0
# 4  2189-06-27 09:13:00  225755  2189-06-27 09:13:00     Date        0

# %%
procedure_events_df = pd.read_csv(PROCEDURE_EVENTS_CSV)

# %%
procedure_events_df.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10000032  29079034  39553978       88981.0  2180-07-23 14:43:00
# 1    10000032  29079034  39553978           NaN  2180-07-23 14:24:00
# 2    10000032  29079034  39553978           NaN  2180-07-23 14:24:00
# 3    10000980  26913865  39765666           NaN  2189-06-27 09:01:00
# 4    10000980  26913865  39765666           NaN  2189-06-27 09:15:00
#
#                endtime                storetime  itemid  value valueuom  ...  \
# 0  2180-07-23 14:44:00      2180-07-23 14:43:00  225966    1.0     None  ...
# 1  2180-07-23 23:50:00  2180-07-23 23:50:49.983  224275  566.0      min  ...
# 2  2180-07-23 23:50:00  2180-07-23 23:50:49.983  224277  566.0      min  ...
# 3  2189-06-27 20:38:00  2189-06-27 20:38:29.047  225794  697.0      min  ...
# 4  2189-06-27 20:38:00  2189-06-27 20:38:29.047  224277  683.0      min  ...
#
#    orderid linkorderid  ordercategoryname  ordercategorydescription  \
# ...

# %%
output_events_df = pd.read_csv(OUTPUT_EVENTS_CSV)

# %%
output_events_df.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10000032  29079034  39553978         88981  2180-07-23 15:00:00
# 1    10000980  26913865  39765666         36518  2189-06-27 09:08:00
# 2    10000980  26913865  39765666         36518  2189-06-27 09:08:00
# 3    10000980  26913865  39765666         36518  2189-06-27 11:00:00
# 4    10000980  26913865  39765666         36518  2189-06-27 13:00:00
#
#              storetime  itemid  value valueuom
# 0  2180-07-23 16:00:00  226560  175.0       ml
# 1  2189-06-27 09:08:00  226559  450.0       ml
# 2  2189-06-27 09:08:00  226633  400.0       ml
# 3  2189-06-27 10:51:00  226559  600.0       ml
# 4  2189-06-27 12:55:00  226559  800.0       ml

# %%
input_events_df = pd.read_csv(INPUT_EVENTS_CSV)

# %%
input_events_df.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10000032  29079034  39553978         66056  2180-07-23 21:10:00
# 1    10000032  29079034  39553978         88981  2180-07-23 17:00:00
# 2    10000032  29079034  39553978         88981  2180-07-23 17:00:00
# 3    10000032  29079034  39553978         88981  2180-07-23 17:33:00
# 4    10000032  29079034  39553978         88981  2180-07-23 18:56:00
#
#                endtime            storetime  itemid      amount amountuom  \
# 0  2180-07-23 21:11:00  2180-07-23 21:10:00  226452  100.000000        ml
# 1  2180-07-23 17:01:00  2180-07-23 18:56:00  226452  200.000000        ml
# 2  2180-07-23 17:30:00  2180-07-23 17:02:00  220862   49.999999        ml
# 3  2180-07-23 18:03:00  2180-07-23 18:16:00  220862   49.999999        ml
# 4  2180-07-23 18:57:00  2180-07-23 18:56:00  226452  100.000000        ml
#
#    ...  ordercomponenttypedescription ordercategorydescription  patientweight  \
# ...

# %%
d_items_df = pd.read_csv(D_ITEMS_CSV)

# %%
d_items_df.head()
# Out:
#    itemid                    label        abbreviation         linksto  \
# 0  220001             Problem List        Problem List     chartevents
# 1  220003       ICU Admission date  ICU Admission date  datetimeevents
# 2  220045               Heart Rate                  HR     chartevents
# 3  220046  Heart rate Alarm - High     HR Alarm - High     chartevents
# 4  220047   Heart Rate Alarm - Low      HR Alarm - Low     chartevents
#
#               category unitname     param_type  lownormalvalue  \
# 0              General      NaN           Text             NaN
# 1                  ADT      NaN  Date and time             NaN
# 2  Routine Vital Signs      bpm        Numeric             NaN
# 3               Alarms      bpm        Numeric             NaN
# 4               Alarms      bpm        Numeric             NaN
#
#    highnormalvalue
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
ingredient_events_df = pd.read_csv(INGREDIENT_EVENTS_CSV)

# %%
ingredient_events_df.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10000032  29079034  39553978         66056  2180-07-23 21:10:00
# 1    10000032  29079034  39553978         66056  2180-07-23 21:10:00
# 2    10000032  29079034  39553978         88981  2180-07-23 17:00:00
# 3    10000032  29079034  39553978         88981  2180-07-23 17:00:00
# 4    10000032  29079034  39553978         88981  2180-07-23 17:00:00
#
#                endtime            storetime  itemid      amount amountuom  \
# 0  2180-07-23 21:11:00  2180-07-23 21:10:00  220490  100.000000        ml
# 1  2180-07-23 21:11:00  2180-07-23 21:10:00  227075  100.000000        ml
# 2  2180-07-23 17:01:00  2180-07-23 18:56:00  220490  200.000000        ml
# 3  2180-07-23 17:01:00  2180-07-23 18:56:00  227075  200.000000        ml
# 4  2180-07-23 17:30:00  2180-07-23 17:02:00  220490   49.999999        ml
#
#     rate  rateuom  orderid  linkorderid statusdescription  originalamount  \
# ...

# %%
from dask import dataframe as pd

# %%
chart_df = pd.read_csv("chartevents.csv",dtype={'caregiver_id': 'float64',
       'value': 'object',
       'valuenum': 'float64',
       'warning': 'float64'})

# %%
chart_df.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10000032  29079034  39553978       47007.0  2180-07-23 21:01:00
# 1    10000032  29079034  39553978       47007.0  2180-07-23 21:01:00
# 2    10000032  29079034  39553978       47007.0  2180-07-23 21:01:00
# 3    10000032  29079034  39553978       47007.0  2180-07-23 22:00:00
# 4    10000032  29079034  39553978       47007.0  2180-07-23 22:00:00
#
#              storetime  itemid value  valuenum valueuom  warning
# 0  2180-07-23 22:15:00  220179    82      82.0     mmHg      0.0
# 1  2180-07-23 22:15:00  220180    59      59.0     mmHg      0.0
# 2  2180-07-23 22:15:00  220181    63      63.0     mmHg      0.0
# 3  2180-07-23 22:15:00  220045    94      94.0      bpm      0.0
# 4  2180-07-23 22:15:00  220179    85      85.0     mmHg      0.0

# %%
ingreadient_df = pd.read_csv("ingredientevents.csv",dtype={'originalrate': 'float64'})

# %%
ingreadient_df.head()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10000032  29079034  39553978         66056  2180-07-23 21:10:00
# 1    10000032  29079034  39553978         66056  2180-07-23 21:10:00
# 2    10000032  29079034  39553978         88981  2180-07-23 17:00:00
# 3    10000032  29079034  39553978         88981  2180-07-23 17:00:00
# 4    10000032  29079034  39553978         88981  2180-07-23 17:00:00
#
#                endtime            storetime  itemid      amount amountuom  \
# 0  2180-07-23 21:11:00  2180-07-23 21:10:00  220490  100.000000        ml
# 1  2180-07-23 21:11:00  2180-07-23 21:10:00  227075  100.000000        ml
# 2  2180-07-23 17:01:00  2180-07-23 18:56:00  220490  200.000000        ml
# 3  2180-07-23 17:01:00  2180-07-23 18:56:00  227075  200.000000        ml
# 4  2180-07-23 17:30:00  2180-07-23 17:02:00  220490   49.999999        ml
#
#     rate  rateuom  orderid  linkorderid statusdescription  originalamount  \
# ...

# %%
input_df = pd.read_csv("inputevents.csv",dtype={'originalamount': 'float64',
       'originalrate': 'float64',
       'totalamount': 'float64'})

# %%
input_df.columns
# Out:
# Index(['subject_id', 'hadm_id', 'stay_id', 'caregiver_id', 'starttime',
#        'endtime', 'storetime', 'itemid', 'amount', 'amountuom', 'rate',
#        'rateuom', 'orderid', 'linkorderid', 'ordercategoryname',
#        'secondaryordercategoryname', 'ordercomponenttypedescription',
#        'ordercategorydescription', 'patientweight', 'totalamount',
#        'totalamountuom', 'isopenbag', 'continueinnextdept',
#        'statusdescription', 'originalamount', 'originalrate'],
#       dtype='object')
