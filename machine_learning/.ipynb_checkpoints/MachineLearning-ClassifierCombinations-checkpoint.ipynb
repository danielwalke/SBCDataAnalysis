# %% [markdown]
# ## Load data

# %%
import sys
 
sys.path.insert(0, "../")

# %%
from dataAnalysis.data.Filter import Filter
import pandas as pd
from dataAnalysis.Constants import *
from dataAnalysis.DataAnalysis import DataAnalysis

data = pd.read_csv(r"../extdata/sbcdata.csv", header=0)
data_analysis = DataAnalysis(data, mimic_data = None)
# Out:
# /home/dwalke/git/sbc/machine_learning/../dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Training:
# Assessable data are 528101 cases and 1015074 CBCs
# Control data are 527038 cases and 1013548 CBCs
# Sepsis data are 1488 cases and 1526 CBCs
# $$$$$$$$$$$$$$$$$$$$
# Testing:
# /home/dwalke/git/sbc/machine_learning/../dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 365794, Sepsis: 490
# Assessable data are 180494 cases and 366284 CBCs
# Control data are 180157 cases and 365794 CBCs
# Sepsis data are 472 cases and 490 CBCs
# /home/dwalke/git/sbc/machine_learning/../dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 437629, Sepsis: 448
# Assessable data are 157922 cases and 438077 CBCs
# Control data are 180157 cases and 437629 CBCs
# Sepsis data are 438 cases and 448 CBCs

# %%
ed_data = data[data["Sender"] == "ED"]
data_analysis_ed = DataAnalysis(ed_data)
y_test_ed = data_analysis_ed.get_y_test()
y_test_ed_gw = data_analysis_ed.get_y_gw()
X_test_ed = data_analysis_ed.get_X_test()
X_test_ed_gw = data_analysis_ed.get_X_gw()
# Out:
# /home/dwalke/git/sbc/machine_learning/../dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Training:
# Assessable data are 120833 cases and 122769 CBCs
# Control data are 119816 cases and 121740 CBCs
# Sepsis data are 1023 cases and 1029 CBCs
# $$$$$$$$$$$$$$$$$$$$
# Testing:
# Controls: 40888, Sepsis: 335
# Assessable data are 40116 cases and 41223 CBCs
# /home/dwalke/git/sbc/machine_learning/../dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# /home/dwalke/git/sbc/machine_learning/../dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Control data are 39796 cases and 40888 CBCs
# Sepsis data are 328 cases and 335 CBCs
# Controls: 54931, Sepsis: 228
# Assessable data are 53413 cases and 55159 CBCs
# Control data are 39796 cases and 54931 CBCs
# Sepsis data are 225 cases and 228 CBCs

# %%
y_train = data_analysis.get_y_train()
X_train = data_analysis.get_X_train()

y_test = data_analysis.get_y_test()
X_test = data_analysis.get_X_test()

y_gw_test = data_analysis.get_y_gw()
X_gw_test = data_analysis.get_X_gw()

# y_mimic = data_analysis.get_y_mimic()
# X_mimic = data_analysis.get_X_mimic()

# %% [markdown]
# ## Metrics definition

# %%
from dataAnalysis.Metrics import Evaluation

evaluation = Evaluation(y_test, y_gw_test, X_test, X_gw_test)
evaluation_ed = Evaluation(y_test_ed, y_test_ed_gw, X_test_ed, X_test_ed_gw)

# %%
from sklearn.metrics import precision_recall_curve
def print_prc(classifier, y_test = y_test):
    y_score = classifier.predict_proba(X_test)[:, 1]
    #calculate precision and recall
    precision, recall, thresholds = precision_recall_curve(y_test, y_score)

    #create precision recall curve
    fig, ax = plt.subplots()
    ax.plot(recall, precision, color='purple')

    #add axis labels to plot
    ax.set_title('Precision-Recall Curve')
    ax.set_ylabel('Precision')
    ax.set_xlabel('Recall')

    #display plot
    plt.show()

# %%
X_test.shape
# Out:
# (366284, 7)

# %%
import numpy as np

X_train = np.concatenate((X_train, X_mimic))
y_train = np.concatenate((y_train, y_mimic))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
# ----> 3 X_train = np.concatenate((X_train, X_mimic))
#       4 y_train = np.concatenate((y_train, y_mimic))
#
# NameError: name 'X_mimic' is not defined

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
import time
start = time.time()
logistic_regression = LogisticRegression(random_state=0, solver="liblinear", class_weight="balanced")
logistic_regression.fit(X_train, y_train)
print(time.time() -start)
print(evaluation.get_df_metrics(logistic_regression))
print(evaluation_ed.get_df_metrics(logistic_regression))
evaluation.plot_confusion_matrix(logistic_regression)
# Out:
# 4.970575571060181
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.044219  0.776133  0.441226   0.008632  0.836916  0.009453
# 1  Greifswald  0.022229  0.592021  0.373617   0.003746  0.755808  0.004283
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.098585  0.734930  0.445111   0.044091  0.824587  0.046106
# 1  Greifswald  0.048166  0.608604  0.385754   0.015774  0.774232  0.024801

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
start = time.time()
decision_tree = DecisionTreeClassifier(random_state=42, max_features=6, min_samples_leaf=0.005,
                       min_samples_split=0.03, class_weight="balanced")
decision_tree.fit(X_train, y_train)
print(time.time() -start)
print(evaluation.get_df_metrics(decision_tree))
evaluation.plot_confusion_matrix(decision_tree)
# Out:
# 3.0719945430755615
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.044252  0.726204  0.424541   0.007894  0.849454  0.009056
# 1  Greifswald  0.027364  0.631928  0.389278   0.004322  0.787637  0.003666

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import time
start = time.time()
random_forest = RandomForestClassifier(class_weight={0: 0.0025, 1: 1}, max_leaf_nodes=79,
                           min_samples_leaf=0.0001,
                           min_samples_split=0.0055,
                           n_estimators=500, random_state=42, n_jobs=-1)
random_forest.fit(X_train, y_train)
print(time.time() -start)
print(evaluation.get_df_metrics(random_forest))
print(evaluation_ed.get_df_metrics(logistic_regression))
evaluation.plot_confusion_matrix(random_forest)
print(random_forest.feature_importances_)
# Out:
# 18.220984935760498
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.060181  0.884278  0.476587   0.014645  0.870140  0.016887
# 1  Greifswald  0.038108  0.840510  0.460436   0.007585  0.817449  0.005784
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.098585  0.734930  0.445111   0.044091  0.824587  0.046106
# 1  Greifswald  0.048166  0.608604  0.385754   0.015774  0.774232  0.024801
# [0.1232475  0.01337177 0.05902818 0.53471879 0.07378854 0.05219423
#  0.14365099]

# %% [markdown]
# ## Differently strict machine learning classifiers I

# %%
import numpy as np
from numpy import argmax
from numpy import sqrt
from sklearn import metrics

fpr, tpr, thresholds = metrics.roc_curve(y_test, random_forest.predict_proba(X_test)[:, 1], pos_label=1)
gmeans = sqrt(tpr * (1-fpr))
ix = argmax(gmeans)

BEST_THRESHOLD = 0.5 # thresholds[ix]
CRITICAL_RANGE = .05
rf_proba = random_forest.predict_proba(X_test)[:, 1]
above_critical = rf_proba >= BEST_THRESHOLD-(CRITICAL_RANGE/2)
below_critical = rf_proba <= BEST_THRESHOLD+(CRITICAL_RANGE/2)
critical_proba = np.logical_and(above_critical, below_critical)
critical_proba.sum()
print(BEST_THRESHOLD)
# Out:
# 0.3277982620869698

# %%
indices = np.where(critical_proba)
pd.DataFrame(rf_proba[indices[0]]).describe()
# Out:
#                   0
# count  14830.000000
# mean       0.326770
# std        0.014428
# min        0.302800
# 25%        0.314232
# 50%        0.326270
# 75%        0.339083
# max        0.352796

# %%
lr_proba = logistic_regression.predict_proba(X_test[indices[0]])[:, 1]
rf_proba[indices] = lr_proba

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
auroc = roc_auc_score(y_test, rf_proba)
auprc = average_precision_score(y_test, rf_proba)
auroc, auprc
# Out:
# (0.8662061606437793, 0.015854732820614746)

# %% [markdown]
# ## All n highest from rf to logistic regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score


clf1 = random_forest
clf2 = logistic_regression

thresholds = np.linspace(0,.5, 20, endpoint=True)
aurocs = []
auprcs = []
for i in thresholds:
    
    THRESHOLD = i
    rf_proba = clf1.predict_proba(X_test)[:, 1]
    highest_scores = rf_proba[rf_proba >= 0.5 + THRESHOLD]
    indices = np.where(highest_scores)[0]
    
    if indices.shape[0] > 0:
        lr_proba = clf2.predict_proba(X_test[indices])[:, 1]
        rf_proba[indices] = lr_proba
    
    auroc = roc_auc_score(y_test, rf_proba)
    auprc = average_precision_score(y_test, rf_proba)
    aurocs.append(auroc)
    auprcs.append(auprc)

fig, ax = plt.subplots(1, 2)
fig.tight_layout(pad=2.0)
plt.subplot(1, 2, 1)
plt.plot(thresholds, aurocs, "b-")
plt.title("AUROC")
plt.subplot(1, 2, 2)
plt.plot(thresholds, auprcs, "g--")
plt.title("AUPRC")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score

thresholds = np.linspace(0,.5, 20, endpoint=True)
aurocs = []
auprcs = []

clf1 = random_forest
clf2 = logistic_regression

SEPERATOR = 0.3277982620869698 #.5

for i in thresholds:
    
    THRESHOLD = i
    rf_proba = clf1.predict_proba(X_test)[:, 1]
    highest_scores = rf_proba >= SEPERATOR - THRESHOLD
    lowest_scores = rf_proba <= SEPERATOR + THRESHOLD
    indices = np.where(np.logical_and(highest_scores, lowest_scores))[0]
    print(indices)
    print(indices.shape)
    if indices.shape[0] > 0:
        lr_proba = clf2.predict_proba(X_test[indices])[:, 1]
        rf_proba[indices] = lr_proba
    
    auroc = roc_auc_score(y_test, rf_proba)
    auprc = average_precision_score(y_test, rf_proba)
    aurocs.append(auroc)
    auprcs.append(auprc)

fig, ax = plt.subplots(1, 2)
fig.tight_layout(pad=2.0)
plt.subplot(1, 2, 1)
plt.plot(thresholds, aurocs, "b-")
plt.title("AUROC")
plt.subplot(1, 2, 2)
plt.plot(thresholds, auprcs, "g--")
plt.title("AUPRC")
plt.show()
# Out:
# [312911]
# (1,)
# [    36     37     53 ... 366185 366219 366256]
# (15630,)
# [    36     37     53 ... 366268 366272 366277]
# (32386,)
# [    36     37     53 ... 366268 366272 366277]
# (50949,)
# [    27     36     37 ... 366272 366274 366277]
# (70824,)
# [     2     15     26 ... 366272 366274 366277]
# (91672,)
# [     2     14     15 ... 366277 366281 366282]
# (114186,)
# [     0      2      6 ... 366278 366281 366282]
# (140724,)
# [     0      2      4 ... 366278 366281 366282]
# (172769,)
# [     0      2      3 ... 366278 366281 366282]
# (209047,)
# [     0      2      3 ... 366281 366282 366283]
# (248757,)
# [     0      2      3 ... 366281 366282 366283]
# (303030,)
# [     0      1      2 ... 366281 366282 366283]
# (345243,)
# [     0      1      2 ... 366281 366282 366283]
# (347919,)
# [     0      1      2 ... 366281 366282 366283]
# (350500,)
# [     0      1      2 ... 366281 366282 366283]
# (352897,)
# [     0      1      2 ... 366281 366282 366283]
# (355522,)
# [     0      1      2 ... 366281 366282 366283]
# (358354,)
# [     0      1      2 ... 366281 366282 366283]
# (361165,)
# [     0      1      2 ... 366281 366282 366283]
# (364534,)

# %%
np.asarray(aurocs).argmax()
# Out:
# 12

# %%
aurocs[12], thresholds[12]
# Out:
# (0.8708505500977298, 0.3157894736842105)

# %% [markdown]
# ## Get false positive from random forest

# %%
import numpy as np
y_pred_proba = random_forest.predict_proba(X_test)[:, 1]
y_pred = np.round(y_pred_proba)
false_pos_mask = np.logical_and((y_pred == 1), (y_test == 0))

X_test_false_pos = X_test[false_pos_mask]
y_test_false_pos = y_test[false_pos_mask]

# %%
X_test.shape
# Out:
# (366284, 7)

# %% [markdown]
# ## Analysis how logistic regression could correct mistakes of the random forest

# %%
false_pos_corr_mask = logistic_regression.predict(X_test_false_pos) == 0
X_false_pos_corr = X_test_false_pos[false_pos_corr_mask]
## distribution of false positive proba according to random forest
pd.DataFrame(random_forest.predict_proba(X_false_pos_corr)[:, 1]).describe()
# Out:
# 10811
# (42016, 7)
# 0.2573067402894136
#                   0
# count  10811.000000
# mean       0.587108
# std        0.070960
# min        0.500004
# 25%        0.532470
# 50%        0.567105
# 75%        0.624540
# max        0.850512

# %%
##  get indexes from sorted
sepsis_pred_mask = np.logical_and((y_pred_proba >= 0.5), (y_test == 0))
sorted_pred_proba = y_pred_proba[sepsis_pred_mask].sort()
print(y_pred_proba[sepsis_pred_mask][np.argsort(y_pred_proba[sepsis_pred_mask])])
# Out:
# [0.50000226 0.50000399 0.50001381 ... 0.86200229 0.86270719 0.86270719]

# %%
## indices of 50 lowest false postive proba according to random forest
np.argsort(y_pred_proba[sepsis_pred_mask])[:50]
# Out:
# array([17033, 33019, 13381, 36308, 24212, 21618, 30324,  2925, 14414,
#        37776,  8457, 15645,    41, 34450, 27720, 32169,  4957, 19863,
#        24132, 10607, 20989, 32320, 24076, 38713, 12318,  6359,  1648,
#         4312,  4441,  3979, 38216,  5064, 30576, 31304,  5881, 20508,
#        31957, 21701, 28502, 35194,  7150, 38117, 34825, 15807, 28490,
#        23839, 37571,  2114, 24138,   243])

# %%
## 50 lowest false postive proba according to random forest
pd.DataFrame(random_forest.predict_proba(X_test[sepsis_pred_mask][np.argsort(y_pred_proba[sepsis_pred_mask])[:50]])[:,1]).describe()
# Out:
#                0
# count  50.000000
# mean    0.500142
# std     0.000083
# min     0.500002
# 25%     0.500071
# 50%     0.500147
# 75%     0.500214
# max     0.500282

# %%
# ## Features dataframe from the 50 lowest false postive proba according to random forest
# from dataAnalysis.Constants import FEATURES
# data_analysis.get_testing_data()[sepsis_pred_mask].iloc[np.argsort(y_pred_proba[sepsis_pred_mask])].iloc[:50].to_csv("50_lowest_false_pos_proba_rf.csv", index=False)

# %%
first_n = []
corrected_pred = []
ratio_corrected_pred = []
for i in [10, 50, 100, 500, 1000, 10_000, 42_258]:
    first_n.append(i)
    corrected_pred.append((logistic_regression.predict(X_test[sepsis_pred_mask][np.argsort(y_pred_proba[sepsis_pred_mask])[:i]]) == 0).sum())
    ratio_corrected_pred.append(((logistic_regression.predict(X_test[sepsis_pred_mask][np.argsort(y_pred_proba[sepsis_pred_mask])[:i]]) == 0).sum() /
          (X_test[sepsis_pred_mask][np.argsort(y_pred_proba[sepsis_pred_mask])[:i]].shape[0]))*100)
df = pd.DataFrame([])
df = df.assign(firstN=first_n)
df = df.assign(correctedPred=corrected_pred)
df = df.assign(ratioCorrectedPredictions=ratio_corrected_pred)
df.set_index("firstN")
# Out:
#         correctedPred  ratioCorrectedPredictions
# firstN
# 10                  4                  40.000000
# 50                 21                  42.000000
# 100                39                  39.000000
# 500               207                  41.400000
# 1000              419                  41.900000
# 10000            4481                  44.810000
# 42258           10811                  25.730674

# %%
from sklearn.ensemble import VotingClassifier

vc = VotingClassifier(estimators=[("rf", random_forest), ("lr",logistic_regression)], voting="soft", n_jobs=10, verbose=True, weights=[100,1])
vc = vc.fit(X_train, y_train)
# Out:
# [Voting] ....................... (2 of 2) Processing lr, total=  12.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       1 from sklearn.ensemble import VotingClassifier
#       3 vc = VotingClassifier(estimators=[("rf", random_forest), ("lr",logistic_regression)], voting="soft", n_jobs=10, verbose=True, weights=[100,1])
# ----> 4 vc = vc.fit(X_train, y_train)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_voting.py:346, in VotingClassifier.fit(self, X, y, sample_weight)
#     343 self.classes_ = self.le_.classes_
#     344 transformed_y = self.le_.transform(y)
# --> 346 return super().fit(X, transformed_y, sample_weight)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_voting.py:81, in _BaseVoting.fit(self, X, y, sample_weight)
#      75 if self.weights is not None and len(self.weights) != len(self.estimators):
#      76     raise ValueError(
#      77         "Number of `estimators` and weights must be equal; got"
#      78         f" {len(self.weights)} weights, {len(self.estimators)} estimators"
#      79     )
# ---> 81 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#      82     delayed(_fit_single_estimator)(
#      83         clone(clf),
#      84         X,
#      85         y,
#      86         sample_weight=sample_weight,
#      87         message_clsname="Voting",
#      88         message=self._log_message(names[idx], idx + 1, len(clfs)),
#      89     )
#      90     for idx, clf in enumerate(clfs)
#      91     if clf != "drop"
#      92 )
#      94 self.named_estimators_ = Bunch()
#      96 # Uses 'drop' as placeholder for dropped estimators
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/.local/lib/python3.10/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
print(evaluation.get_df_metrics(vc))
# Out:
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.060118  0.884090  0.476523   0.014622  0.870049  0.015847
# 1  Greifswald  0.038023  0.840049  0.460289   0.007563  0.818359  0.005698

# %%
print(evaluation.get_df_metrics(logistic_regression))
# Out:
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.044219  0.776133  0.441226   0.008632  0.836916  0.009453
# 1  Greifswald  0.022229  0.592021  0.373617   0.003746  0.755808  0.004283

# %% [markdown]
# ## XG Boost

# %%
from xgboost import XGBClassifier

start = time.time()
# xgb_classifier = XGBClassifier(tree_method='gpu_hist', 
#                            scale_pos_weight = 660,
#                            n_estimators=478,
#                            max_depth=2,
#                            eta=0.1,
#                            min_child_weight = 7,
#                            max_delta_step= 7,
#                            sampling_method= "uniform")
xgb_classifier = XGBClassifier(tree_method='gpu_hist', 
                           scale_pos_weight = 70,
                           n_estimators=1000,
                           max_depth=2,
                           eta=0.1,
                           min_child_weight = 7,
                           max_delta_step= 7,
                           sampling_method= "uniform")
xgb_classifier.fit(X_train, y_train)
print(time.time() -start)
print(evaluation.get_df_metrics(xgb_classifier))
evaluation.plot_confusion_matrix(xgb_classifier)
# Out:
# 3.0342214107513428
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.078705  0.980769  0.515829   0.041372  0.875481  0.018280
# 1  Greifswald  0.039413  0.959589  0.496704   0.014035  0.808292  0.006737

# %% [markdown]
# ## RUS Boost

# %%
from imblearn.ensemble import RUSBoostClassifier
from sklearn.tree import DecisionTreeClassifier
import time
start = time.time()
rus_boost = RUSBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=79, min_samples_leaf= 5, min_samples_split = 10),
                   learning_rate=0.90369, n_estimators=495,
                   random_state=1714400672, sampling_strategy=35/65)
rus_boost.fit(X_train, y_train)
print(time.time() -start)
print(evaluation.get_df_metrics(rus_boost))
evaluation.plot_confusion_matrix(rus_boost)
# Out:
# /home/dwalke/.local/lib/python3.10/site-packages/imblearn/ensemble/_weight_boosting.py:267: FutureWarning: `base_estimator` was renamed to `estimator` in version 0.10 and will be removed in 0.12.
#   warnings.warn(
# 229.92461347579956
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.056904  0.864288  0.470080   0.013025  0.867951  0.016951
# 1  Greifswald  0.035836  0.806673  0.449801   0.006685  0.815194  0.006096

# %% [markdown]
# ## Feature variation

# %%
from dataAnalysis.FeatureImportance import FeatureImportance
feature_importance = FeatureImportance(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from dataAnalysis.FeatureImportance import FeatureImportance
# ----> 2 feature_importance_large = FeatureImportance(X_train, is_normalize=False, steps = 20)
#       3 feature_importance_small = FeatureImportance(X_train, is_normalize=False, steps = 14)
#
# NameError: name 'X_train' is not defined

# %%
feature_importance.plot_feature_importance(logistic_regression, title = "Logistic regression")
feature_importance.plot_feature_importance(decision_tree, title="Decision tree")
feature_importance.plot_feature_importance(random_forest, title="Random forest")
feature_importance.plot_feature_importance(xgb_classifier, title="XGBoost")
feature_importance.plot_feature_importance(rus_boost, title="RUSBoost")
# Out:
# Ratio of diseased men/women over all CBCs for Logistic regression 42.1359171875	34.250071874999996
# Ratio of diseased men/women over all CBCs for Decision tree 30.6701875	30.6701875
# Ratio of diseased men/women over all CBCs for Random forest 16.9663828125	15.3475515625
# Ratio of diseased men/women over all CBCs for XGBoost 24.2523328125	19.2157484375
# Ratio of diseased men/women over all CBCs for RUSBoost 22.4714078125	21.386048437499998

# %% [markdown]
# ## Feature Variation II - Die Rache der unrealistischen Werteverteilung

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from dataAnalysis.Constants import SEX_CATEGORY_COLUMN_NAME
def write_feature_variation(model, model_name):
    QUANTILES = 20
    quantiles = np.linspace(0, 1, QUANTILES+1, endpoint=True)

    X_all = np.concatenate((X_train, X_test, X_gw_test))
    y_pred_all = model.predict(X_all)

    for feature_it in range(len(FEATURES)):
        if FEATURES[feature_it] == SEX_CATEGORY_COLUMN_NAME:
            continue
        path = f"{FEATURES[feature_it]}-Real.csv"
        df = pd.read_csv(path) if os.path.isfile(path) else pd.DataFrame()
        tensor_quantiles = np.quantile(X_all[:, feature_it], quantiles)
        tensor_quantiles_unnormalized = tensor_quantiles
        x_ticks = [(tensor_quantiles_unnormalized.tolist()[j]+tensor_quantiles_unnormalized.tolist()[j+1]) / 2 for j in range(len(tensor_quantiles_unnormalized.tolist()) - 1)]
        x_labels = [f"{tensor_quantiles_unnormalized.tolist()[j]}<= {tensor_quantiles_unnormalized.tolist()[j+1]}" if j == 0 else f"<= {tensor_quantiles_unnormalized.tolist()[j+1]}" for j in range(len(tensor_quantiles_unnormalized.tolist()) - 1)]
        tensor_quantiles[-1] = tensor_quantiles[-1] + 1e-5
        sepsis_ratios = []
        for i in range(tensor_quantiles.shape[0]-1):
            quantile_u = tensor_quantiles[i]
            quantile_o = tensor_quantiles[i+1]
            mask = np.logical_and(X_all[:, feature_it] >= quantile_u, X_all[:, feature_it] < quantile_o)
            sepsis_ratio = y_pred_all[mask].sum() / mask.sum()
            sepsis_ratios.append(sepsis_ratio.item())
        df["x"] = x_labels
        df[model_name] =sepsis_ratios
        plt.figure(figsize=(20, 5))
        plt.plot(x_labels,  sepsis_ratios)
        plt.title(FEATURES[feature_it])
        plt.show()
        df.to_csv(path, index=False)

# %%
write_feature_variation(logistic_regression, "LR")
write_feature_variation(decision_tree, "DT")
write_feature_variation(random_forest, "RF")
write_feature_variation(xgb_classifier, "XGBoost")
write_feature_variation(rus_boost, "RUSBoost")

# %% [markdown]
# ## Error evaluation

# %%
import time

def error_evaluation(model):
    global X_train, y_train, evaluation
    dfs = []
    times = []
    for i in range(100):
        start = time.time()
        model.fit(X_train, y_train)
        times.append(time.time() - start)
        dfs.append(evaluation.get_df_metrics(model))
    return dfs, times

# %%
from sklearn.linear_model import LogisticRegression
logistic_regression = LogisticRegression(solver="liblinear", class_weight="balanced")
dfs, times = error_evaluation(logistic_regression)
for t in times:
    print(t)
for df in dfs:
    print(df)

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(class_weight="balanced", max_features=6, min_samples_leaf=0.005,
                           min_samples_split=0.03)
dfs, times = error_evaluation(decision_tree)
for t in times:
    print(t)
for df in dfs:
    print(df)

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(class_weight={0: 0.0025, 1: 1}, max_leaf_nodes=79,
                           min_samples_leaf=0.0001,
                           min_samples_split=0.0055,
                           n_estimators=500)
dfs, times = error_evaluation(random_forest)
for t in times:
    print(t)
for df in dfs:
    print(df)

# %%
from xgboost import XGBClassifier
xgb_classifier = XGBClassifier(tree_method='gpu_hist', 
                           scale_pos_weight = 660,
                           n_estimators=478,
                           max_depth=2,
                           eta=0.1,
                           min_child_weight = 7,
                           max_delta_step= 7,
                           sampling_method= "uniform")

dfs, times = error_evaluation(xgb_classifier)
for t in times:
    print(t)
for df in dfs:
    print(df)

# %%
from imblearn.ensemble import RUSBoostClassifier
from sklearn.tree import DecisionTreeClassifier

rus_boost = RUSBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=79, min_samples_leaf= 5, min_samples_split = 10),
                   learning_rate=0.90369, n_estimators=495, sampling_strategy=35/65)
dfs, times = error_evaluation(rus_boost)
for t in times:
    print(t)
for df in dfs:
    print(df)

# %% [markdown]
# ## Grid Search

# %%
from sklearn.model_selection import GridSearchCV

def get_best_estimator(model, param_grid):
    grid = GridSearchCV(
    n_jobs=-1,
    cv=10,
    estimator=model,
    scoring=['roc_auc', "balanced_accuracy"],
    refit="balanced_accuracy",#'auroc',
    return_train_score=True,
    param_grid=param_grid,
    verbose= 10
    )
    grid.fit(X_train, y_train)
    return grid.best_estimator_

# %%
from sklearn.linear_model import LogisticRegression

param_grid = {
    'max_iter': [100, 1000, 10000],
    'class_weight': ["balanced", 35/65, 40/60, 45/55],
    "penalty":["l1", "l2", None, "elasticnet"],
    "solver":["liblinear", "saga", "newton-cholesky"]
}
logistic_regression = get_best_estimator(LogisticRegression(random_state=0), param_grid)

# %%
from sklearn.tree import DecisionTreeClassifier

param_grid = {
                'class_weight': [{
                    0:i,
                    1: 1
                } for i in np.linspace(0.01, 0.01, 100)]
}
decision_tree = get_best_estimator(DecisionTreeClassifier(random_state=42, max_features=6, min_samples_leaf=0.005,
                       min_samples_split=0.03), param_grid)

# %%
from sklearn.ensemble import RandomForestClassifier
param_grid={
                'class_weight': [{
                    0:i,
                    1: 1
                } for i in np.linspace(0.0024, 0.0026, 4)],
        'n_estimators': range(495, 595, 10)
    }
random_forest = get_best_estimator(RandomForestClassifier(max_leaf_nodes=79,
                           min_samples_leaf=0.0001,
                           min_samples_split=0.0055,
                           n_estimators=500, random_state=42), param_grid)

# %%
un, counts = np.unique(y_train, return_counts=True)
counts[0]/counts[1]
# Out:
# 864.0781483325037

# %%
from xgboost import XGBClassifier
param_grid = {
    'max_depth': [2],
    'learning_rate': [0.1],
    'gamma': [0],
    'reg_lambda': [10],
    'scale_pos_weight': [1, 2, 4, 8, 16, 30, 50, 100, 150, 200, 400, 500,550, 600, 650, 700, 800, 850, 900],
    "min_child_weight": [7],
    "max_delta_step": [6],
    'n_estimators': [2, 5, 10, 15, 20, 50, 80, 100, 200, 300, 400, 450, 500, 550, 600, 700, 750, 800, 900, 1000, 1200, 1400]
}
xgb_classifier = get_best_estimator(XGBClassifier(tree_method='gpu_hist', gpu_id = 0,
                                                        seed = 42), param_grid)
# Out:
# Fitting 10 folds for each of 418 candidates, totalling 4180 fits
# [CV 5/10; 1/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1
# [CV 5/10; 1/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.648, test=0.629) total time=   9.7s
# [CV 6/10; 7/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50
# [CV 6/10; 7/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.741, test=0.747) total time=   4.8s
# [CV 3/10; 13/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=550
# [CV 3/10; 13/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.712, test=0.701) roc_auc: (train=0.783, test=0.791) total time=   5.7s
# [CV 6/10; 16/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=700
# [CV 6/10; 16/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=700; balanced_accuracy: (train=0.743, test=0.735) roc_auc: (train=0.795, test=0.789) total time=   5.9s
# [CV 8/10; 22/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=4
# [CV 8/10; 22/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=4; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.731, test=0.725) total time=   6.0s
# [CV 1/10; 29/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=200
# [CV 1/10; 29/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=200; balanced_accuracy: (train=0.636, test=0.645) roc_auc: (train=0.787, test=0.797) total time=   6.1s
# [CV 5/10; 35/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=700
# [CV 5/10; 35/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=700; balanced_accuracy: (train=0.745, test=0.748) roc_auc: (train=0.805, test=0.809) total time=   6.2s
# [CV 9/10; 41/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=4
# [CV 9/10; 41/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=4; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.740, test=0.764) total time=   6.2s
# [CV 2/10; 48/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=200
# [CV 2/10; 48/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=200; balanced_accuracy: (train=0.666, test=0.659) roc_auc: (train=0.811, test=0.821) total time=   6.3s
# [CV 6/10; 54/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=700
# [CV 6/10; 54/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=700; balanced_accuracy: (train=0.747, test=0.740) roc_auc: (train=0.825, test=0.812) total time=   6.4s
# [CV 8/10; 60/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=4
# [CV 8/10; 60/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=4; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.731, test=0.725) total time=   6.4s
# [CV 10/10; 66/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=150
# [CV 10/10; 66/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=150; balanced_accuracy: (train=0.630, test=0.612) roc_auc: (train=0.822, test=0.782) total time=   6.4s
# [CV 4/10; 73/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=700
# [CV 4/10; 73/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=700; balanced_accuracy: (train=0.754, test=0.758) roc_auc: (train=0.832, test=0.834) total time=   6.5s
# [CV 7/10; 79/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=4
# [CV 7/10; 79/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=4; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.795, test=0.790) total time=   6.5s
# [CV 10/10; 85/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=150
# [CV 10/10; 85/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=150; balanced_accuracy: (train=0.637, test=0.618) roc_auc: (train=0.831, test=0.791) total time=   6.5s
# [CV 4/10; 92/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=700
# [CV 4/10; 92/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=700; balanced_accuracy: (train=0.756, test=0.750) roc_auc: (train=0.839, test=0.840) total time=   6.5s
# [CV 8/10; 98/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=4
# [CV 8/10; 98/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=4; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.817, test=0.806) total time=   6.7s
# [CV 1/10; 105/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=200
# [CV 1/10; 105/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=200; balanced_accuracy: (train=0.676, test=0.670) roc_auc: (train=0.852, test=0.857) total time=   6.9s
# [CV 1/10; 111/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=700
# [CV 1/10; 111/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=700; balanced_accuracy: (train=0.770, test=0.758) roc_auc: (train=0.853, test=0.860) total time=   7.6s
# [CV 3/10; 117/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=4
# [CV 3/10; 117/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=4; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.845, test=0.856) total time=   7.9s
# [CV 7/10; 1/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1
# [CV 7/10; 1/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.644, test=0.660) total time=  10.2s
# [CV 8/10; 7/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50
# [CV 8/10; 7/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.731, test=0.725) total time=   4.7s
# [CV 2/10; 14/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600
# [CV 2/10; 14/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.721, test=0.714) roc_auc: (train=0.792, test=0.797) total time=   5.7s
# [CV 3/10; 19/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=900
# [CV 3/10; 19/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.741, test=0.756) roc_auc: (train=0.794, test=0.807) total time=   5.9s
# [CV 1/10; 24/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=16
# [CV 1/10; 24/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.742, test=0.745) total time=   5.9s
# [CV 3/10; 30/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=400
# [CV 3/10; 30/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=400; balanced_accuracy: (train=0.712, test=0.700) roc_auc: (train=0.805, test=0.814) total time=   6.1s
# [CV 5/10; 36/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=800
# [CV 5/10; 36/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=800; balanced_accuracy: (train=0.746, test=0.752) roc_auc: (train=0.806, test=0.810) total time=   6.1s
# [CV 6/10; 42/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=8
# [CV 6/10; 42/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=8; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.742, test=0.747) total time=   6.1s
# [CV 9/10; 48/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=200
# [CV 9/10; 48/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=200; balanced_accuracy: (train=0.661, test=0.659) roc_auc: (train=0.814, test=0.822) total time=   6.2s
# [CV 3/10; 55/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=800
# [CV 3/10; 55/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=800; balanced_accuracy: (train=0.749, test=0.761) roc_auc: (train=0.826, test=0.833) total time=   6.3s
# [CV 7/10; 61/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=8
# [CV 7/10; 61/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=8; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.795, test=0.790) total time=   6.3s
# [CV 1/10; 68/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=400
# [CV 1/10; 68/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=400; balanced_accuracy: (train=0.720, test=0.725) roc_auc: (train=0.829, test=0.838) total time=   6.3s
# [CV 5/10; 74/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=800
# [CV 5/10; 74/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=800; balanced_accuracy: (train=0.754, test=0.758) roc_auc: (train=0.835, test=0.836) total time=   6.4s
# [CV 9/10; 80/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=8
# [CV 9/10; 80/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=8; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.796, test=0.805) total time=   6.4s
# [CV 3/10; 87/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=400
# [CV 3/10; 87/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=400; balanced_accuracy: (train=0.727, test=0.715) roc_auc: (train=0.835, test=0.843) total time=   6.4s
# [CV 5/10; 93/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=800
# [CV 5/10; 93/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=800; balanced_accuracy: (train=0.759, test=0.767) roc_auc: (train=0.838, test=0.840) total time=   6.5s
# [CV 8/10; 99/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=8
# [CV 8/10; 99/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=8; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.828, test=0.819) total time=   6.6s
# [CV 2/10; 106/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=400
# [CV 2/10; 106/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=400; balanced_accuracy: (train=0.739, test=0.741) roc_auc: (train=0.852, test=0.863) total time=   6.7s
# [CV 6/10; 112/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=800
# [CV 6/10; 112/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=800; balanced_accuracy: (train=0.769, test=0.764) roc_auc: (train=0.854, test=0.844) total time=   6.7s
# [CV 10/10; 118/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=8
# [CV 10/10; 118/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=8; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.852, test=0.811) total time=  10.1s
# [CV 4/10; 1/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1
# [CV 4/10; 1/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.646, test=0.645) total time=  10.5s
# [CV 9/10; 7/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50
# [CV 9/10; 7/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.739, test=0.762) total time=   5.7s
# [CV 4/10; 14/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600
# [CV 4/10; 14/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.715, test=0.715) roc_auc: (train=0.781, test=0.785) total time=   6.0s
# [CV 8/10; 20/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=1
# [CV 8/10; 20/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.646, test=0.633) total time=   6.1s
# [CV 2/10; 27/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=100
# [CV 2/10; 27/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.594, test=0.589) roc_auc: (train=0.799, test=0.806) total time=   6.0s
# [CV 6/10; 33/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=600
# [CV 6/10; 33/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.722, test=0.731) roc_auc: (train=0.808, test=0.797) total time=   6.0s
# [CV 10/10; 39/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=1
# [CV 10/10; 39/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.672, test=0.648) total time=   6.1s
# [CV 3/10; 46/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=100
# [CV 3/10; 46/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.591, test=0.596) roc_auc: (train=0.800, test=0.811) total time=   6.1s
# [CV 2/10; 51/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=550
# [CV 2/10; 51/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.729, test=0.723) roc_auc: (train=0.824, test=0.829) total time=   6.1s
# [CV 2/10; 57/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=900
# [CV 2/10; 57/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.754, test=0.767) roc_auc: (train=0.826, test=0.837) total time=   6.2s
# [CV 3/10; 63/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=30
# [CV 3/10; 63/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.799, test=0.809) total time=   6.2s
# [CV 8/10; 69/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=500
# [CV 8/10; 69/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.732, test=0.726) roc_auc: (train=0.833, test=0.821) total time=   6.3s
# [CV 9/10; 75/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=850
# [CV 9/10; 75/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.758, test=0.760) roc_auc: (train=0.832, test=0.833) total time=   6.3s
# [CV 2/10; 82/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=30
# [CV 2/10; 82/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.804, test=0.810) total time=   6.3s
# [CV 4/10; 88/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=500
# [CV 4/10; 88/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.731, test=0.723) roc_auc: (train=0.838, test=0.839) total time=   6.4s
# [CV 8/10; 94/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=850
# [CV 8/10; 94/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.761, test=0.743) roc_auc: (train=0.841, test=0.825) total time=   6.4s
# [CV 10/10; 100/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=16
# [CV 10/10; 100/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.841, test=0.802) total time=   6.8s
# [CV 4/10; 107/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=500
# [CV 4/10; 107/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.754, test=0.739) roc_auc: (train=0.855, test=0.846) total time=   6.7s
# [CV 8/10; 113/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=850
# [CV 8/10; 113/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.772, test=0.761) roc_auc: (train=0.856, test=0.836) total time=   6.8s
# [CV 1/10; 120/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=30
# [CV 1/10; 120/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.502, test=0.502) roc_auc: (train=0.851, test=0.856) total time=  10.3s
# [CV 2/10; 1/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1
# [CV 2/10; 1/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.646, test=0.634) total time=  10.1s
# [CV 7/10; 7/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50
# [CV 7/10; 7/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.741, test=0.748) total time=   4.8s
# [CV 1/10; 14/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600
# [CV 1/10; 14/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.716, test=0.718) roc_auc: (train=0.784, test=0.793) total time=   5.7s
# [CV 6/10; 18/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=850
# [CV 6/10; 18/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.744, test=0.732) roc_auc: (train=0.797, test=0.788) total time=   6.1s
# [CV 4/10; 24/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=16
# [CV 4/10; 24/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.741, test=0.746) total time=   6.1s
# [CV 7/10; 30/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=400
# [CV 7/10; 30/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=400; balanced_accuracy: (train=0.711, test=0.726) roc_auc: (train=0.802, test=0.799) total time=   6.1s
# [CV 1/10; 37/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=850
# [CV 1/10; 37/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.748, test=0.763) roc_auc: (train=0.805, test=0.814) total time=   6.2s
# [CV 5/10; 43/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=16
# [CV 5/10; 43/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.794, test=0.799) total time=   6.2s
# [CV 8/10; 49/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=400
# [CV 8/10; 49/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=400; balanced_accuracy: (train=0.714, test=0.714) roc_auc: (train=0.824, test=0.813) total time=   6.4s
# [CV 2/10; 56/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=850
# [CV 2/10; 56/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.754, test=0.768) roc_auc: (train=0.826, test=0.837) total time=   6.4s
# [CV 4/10; 62/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=16
# [CV 4/10; 62/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.799, test=0.806) total time=   6.3s
# [CV 8/10; 68/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=400
# [CV 8/10; 68/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=400; balanced_accuracy: (train=0.721, test=0.721) roc_auc: (train=0.832, test=0.821) total time=   6.4s
# [CV 2/10; 75/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=850
# [CV 2/10; 75/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.757, test=0.765) roc_auc: (train=0.833, test=0.841) total time=   6.4s
# [CV 8/10; 81/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=16
# [CV 8/10; 81/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.799, test=0.786) total time=   6.4s
# [CV 2/10; 88/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=500
# [CV 2/10; 88/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.735, test=0.732) roc_auc: (train=0.835, test=0.843) total time=   6.5s
# [CV 6/10; 94/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=850
# [CV 6/10; 94/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.761, test=0.754) roc_auc: (train=0.840, test=0.829) total time=   6.6s
# [CV 1/10; 101/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=30
# [CV 1/10; 101/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.841, test=0.847) total time=   6.8s
# [CV 5/10; 107/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=500
# [CV 5/10; 107/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.752, test=0.748) roc_auc: (train=0.855, test=0.854) total time=   6.8s
# [CV 9/10; 113/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=850
# [CV 9/10; 113/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.770, test=0.776) roc_auc: (train=0.853, test=0.854) total time=   6.9s
# [CV 4/10; 120/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=30
# [CV 4/10; 120/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.503, test=0.504) roc_auc: (train=0.854, test=0.846) total time=  10.3s
# [CV 8/10; 1/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1
# [CV 8/10; 1/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.646, test=0.633) total time=  12.5s
# [CV 2/10; 8/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=100
# [CV 2/10; 8/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.638, test=0.624) roc_auc: (train=0.767, test=0.784) total time=   6.2s
# [CV 5/10; 14/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600
# [CV 5/10; 14/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.713, test=0.697) roc_auc: (train=0.786, test=0.781) total time=   6.4s
# [CV 9/10; 20/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=1
# [CV 9/10; 20/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.670, test=0.683) total time=   6.3s
# [CV 3/10; 27/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=100
# [CV 3/10; 27/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.591, test=0.596) roc_auc: (train=0.798, test=0.807) total time=   6.3s
# [CV 7/10; 33/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=600
# [CV 7/10; 33/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.727, test=0.737) roc_auc: (train=0.808, test=0.803) total time=   6.3s
# [CV 1/10; 40/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=2
# [CV 1/10; 40/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=2; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.726, test=0.731) total time=   6.3s
# [CV 5/10; 46/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=100
# [CV 5/10; 46/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.607, test=0.594) roc_auc: (train=0.800, test=0.801) total time=   6.2s
# [CV 9/10; 52/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=600
# [CV 9/10; 52/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.733, test=0.751) roc_auc: (train=0.826, test=0.826) total time=   6.3s
# [CV 3/10; 59/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=2
# [CV 3/10; 59/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=2; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.727, test=0.720) total time=   6.3s
# [CV 7/10; 65/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=100
# [CV 7/10; 65/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.595, test=0.612) roc_auc: (train=0.814, test=0.808) total time=   6.3s
# [CV 9/10; 71/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=600
# [CV 9/10; 71/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.733, test=0.749) roc_auc: (train=0.832, test=0.834) total time=   6.4s
# [CV 10/10; 77/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=1
# [CV 10/10; 77/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.730, test=0.696) total time=   6.5s
# [CV 10/10; 83/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=50
# [CV 10/10; 83/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.812, test=0.772) total time=   6.6s
# [CV 10/10; 89/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=550
# [CV 10/10; 89/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.745, test=0.709) roc_auc: (train=0.841, test=0.803) total time=   6.4s
# [CV 3/10; 96/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=1
# [CV 3/10; 96/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.796, test=0.808) total time=   6.6s
# [CV 7/10; 102/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=50
# [CV 7/10; 102/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.505, test=0.512) roc_auc: (train=0.846, test=0.836) total time=   6.9s
# [CV 1/10; 109/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=600
# [CV 1/10; 109/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.763, test=0.754) roc_auc: (train=0.854, test=0.860) total time=   6.7s
# [CV 5/10; 115/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=1
# [CV 5/10; 115/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.838, test=0.841) total time=   7.2s
# [CV 9/10; 121/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=50
# [CV 9/10; 121/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=80, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.521, test=0.525) roc_auc: (train=0.854, test=0.852) total time=   7.9s
# [CV 9/10; 1/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1
# [CV 9/10; 1/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.643, test=0.658) total time=  12.4s
# [CV 3/10; 8/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=100
# [CV 3/10; 8/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.768, test=0.776) total time=   6.4s
# [CV 7/10; 14/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600
# [CV 7/10; 14/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=2, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.714, test=0.721) roc_auc: (train=0.787, test=0.784) total time=   6.4s
# [CV 10/10; 20/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=1
# [CV 10/10; 20/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.672, test=0.647) total time=   6.4s
# [CV 4/10; 27/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=100
# [CV 4/10; 27/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.606, test=0.603) roc_auc: (train=0.798, test=0.804) total time=   6.4s
# [CV 8/10; 33/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=600
# [CV 8/10; 33/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=5, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.725, test=0.723) roc_auc: (train=0.806, test=0.795) total time=   6.4s
# [CV 2/10; 40/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=2
# [CV 2/10; 40/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=2; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.727, test=0.717) total time=   6.3s
# [CV 6/10; 46/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=100
# [CV 6/10; 46/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.604, test=0.604) roc_auc: (train=0.802, test=0.794) total time=   6.3s
# [CV 10/10; 52/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=600
# [CV 10/10; 52/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=10, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.735, test=0.705) roc_auc: (train=0.827, test=0.791) total time=   6.3s
# [CV 4/10; 59/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=2
# [CV 4/10; 59/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=2; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.726, test=0.731) total time=   6.3s
# [CV 8/10; 65/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=100
# [CV 8/10; 65/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.579, test=0.571) roc_auc: (train=0.814, test=0.801) total time=   6.2s
# [CV 1/10; 72/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=650
# [CV 1/10; 72/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=15, reg_lambda=10, scale_pos_weight=650; balanced_accuracy: (train=0.750, test=0.745) roc_auc: (train=0.832, test=0.843) total time=   6.4s
# [CV 4/10; 78/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=2
# [CV 4/10; 78/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=2; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.726, test=0.731) total time=   6.6s
# [CV 5/10; 84/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=100
# [CV 5/10; 84/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=100; balanced_accuracy: (train=0.588, test=0.577) roc_auc: (train=0.819, test=0.824) total time=   6.5s
# [CV 5/10; 90/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=600
# [CV 5/10; 90/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=20, reg_lambda=10, scale_pos_weight=600; balanced_accuracy: (train=0.741, test=0.738) roc_auc: (train=0.840, test=0.839) total time=   6.4s
# [CV 7/10; 96/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=1
# [CV 7/10; 96/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=1; balanced_accuracy: (train=0.500, test=0.500) roc_auc: (train=0.799, test=0.795) total time=   6.9s
# [CV 9/10; 102/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=50
# [CV 9/10; 102/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.507, test=0.507) roc_auc: (train=0.845, test=0.846) total time=   6.7s
# [CV 3/10; 109/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=50, reg_lambda=10, scale_pos_weight=600
# ...
# [CV 6/10; 393/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=550
# [CV 6/10; 393/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.798, test=0.767) roc_auc: (train=0.894, test=0.868) total time= 2.8min
# [CV 8/10; 399/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900
# [CV 8/10; 399/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.812, test=0.774) roc_auc: (train=0.894, test=0.855) total time= 2.9min
# [CV 1/10; 406/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=50
# [CV 1/10; 406/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.579, test=0.559) roc_auc: (train=0.891, test=0.871) total time= 3.1min
# [CV 7/10; 412/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550
# [CV 7/10; 412/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.800, test=0.775) roc_auc: (train=0.896, test=0.867) total time= 3.0min
# [CV 10/10; 418/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900
# [CV 10/10; 418/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.818, test=0.748) roc_auc: (train=0.900, test=0.834) total time= 1.9min
# [CV 7/10; 386/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=30
# [CV 7/10; 386/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.533, test=0.530) roc_auc: (train=0.888, test=0.866) total time= 2.6min
# [CV 10/10; 392/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=500
# [CV 10/10; 392/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.794, test=0.730) roc_auc: (train=0.897, test=0.834) total time= 2.9min
# [CV 4/10; 399/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900
# [CV 4/10; 399/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.813, test=0.762) roc_auc: (train=0.894, test=0.848) total time= 2.9min
# [CV 8/10; 405/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=30
# [CV 8/10; 405/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.539, test=0.512) roc_auc: (train=0.890, test=0.855) total time= 3.1min
# [CV 10/10; 411/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=500
# [CV 10/10; 411/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.796, test=0.730) roc_auc: (train=0.899, test=0.834) total time= 3.0min
# [CV 3/10; 418/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900
# [CV 3/10; 418/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.813, test=0.788) roc_auc: (train=0.895, test=0.866) total time= 2.0min
# [CV 7/10; 380/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=900
# [CV 7/10; 380/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.809, test=0.783) roc_auc: (train=0.891, test=0.865) total time= 2.1min
# [CV 1/10; 387/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=50
# [CV 1/10; 387/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.577, test=0.559) roc_auc: (train=0.888, test=0.872) total time= 2.5min
# [CV 5/10; 393/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=550
# [CV 5/10; 393/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.799, test=0.754) roc_auc: (train=0.895, test=0.862) total time= 2.8min
# [CV 10/10; 399/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900
# [CV 10/10; 399/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.814, test=0.753) roc_auc: (train=0.897, test=0.835) total time= 2.9min
# [CV 4/10; 406/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=50
# [CV 4/10; 406/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.579, test=0.558) roc_auc: (train=0.891, test=0.850) total time= 3.1min
# [CV 6/10; 412/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550
# [CV 6/10; 412/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.801, test=0.761) roc_auc: (train=0.896, test=0.868) total time= 3.0min
# [CV 9/10; 418/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900
# [CV 9/10; 418/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.814, test=0.784) roc_auc: (train=0.897, test=0.866) total time= 1.9min
# [CV 1/10; 386/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=30
# [CV 1/10; 386/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.534, test=0.529) roc_auc: (train=0.887, test=0.872) total time= 2.7min
# [CV 5/10; 392/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=500
# [CV 5/10; 392/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.794, test=0.750) roc_auc: (train=0.894, test=0.861) total time= 2.9min
# [CV 10/10; 398/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=850
# [CV 10/10; 398/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.815, test=0.748) roc_auc: (train=0.897, test=0.833) total time= 2.8min
# [CV 6/10; 405/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=30
# [CV 6/10; 405/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=30; balanced_accuracy: (train=0.537, test=0.516) roc_auc: (train=0.889, test=0.867) total time= 3.1min
# [CV 1/10; 412/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550
# [CV 1/10; 412/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.801, test=0.757) roc_auc: (train=0.896, test=0.869) total time= 3.0min
# [CV 6/10; 418/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900
# [CV 6/10; 418/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.813, test=0.780) roc_auc: (train=0.897, test=0.868) total time= 2.0min
# [CV 9/10; 380/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=900
# [CV 9/10; 380/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.808, test=0.790) roc_auc: (train=0.891, test=0.868) total time= 2.1min
# [CV 3/10; 387/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=50
# [CV 3/10; 387/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.575, test=0.574) roc_auc: (train=0.887, test=0.875) total time= 2.5min
# [CV 7/10; 393/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=550
# [CV 7/10; 393/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.796, test=0.770) roc_auc: (train=0.894, test=0.866) total time= 2.8min
# [CV 9/10; 399/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900
# [CV 9/10; 399/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.811, test=0.784) roc_auc: (train=0.894, test=0.867) total time= 2.9min
# [CV 2/10; 406/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=50
# [CV 2/10; 406/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=50; balanced_accuracy: (train=0.579, test=0.562) roc_auc: (train=0.890, test=0.871) total time= 3.0min
# [CV 5/10; 412/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550
# [CV 5/10; 412/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=550; balanced_accuracy: (train=0.801, test=0.755) roc_auc: (train=0.897, test=0.862) total time= 3.0min
# [CV 5/10; 418/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900
# [CV 5/10; 418/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=900; balanced_accuracy: (train=0.815, test=0.777) roc_auc: (train=0.897, test=0.861) total time= 2.0min
# [CV 5/10; 379/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=850
# [CV 5/10; 379/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.808, test=0.777) roc_auc: (train=0.892, test=0.862) total time= 2.1min
# [CV 9/10; 385/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=16
# [CV 9/10; 385/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.512, test=0.505) roc_auc: (train=0.886, test=0.869) total time= 2.7min
# [CV 3/10; 392/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=500
# [CV 3/10; 392/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.792, test=0.782) roc_auc: (train=0.892, test=0.870) total time= 2.9min
# [CV 5/10; 398/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=850
# [CV 5/10; 398/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1200, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.812, test=0.775) roc_auc: (train=0.895, test=0.861) total time= 2.8min
# [CV 9/10; 404/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=16
# [CV 9/10; 404/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=16; balanced_accuracy: (train=0.513, test=0.505) roc_auc: (train=0.888, test=0.870) total time= 3.1min
# [CV 4/10; 411/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=500
# [CV 4/10; 411/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=500; balanced_accuracy: (train=0.795, test=0.753) roc_auc: (train=0.896, test=0.848) total time= 3.0min
# [CV 8/10; 417/418] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=850
# [CV 8/10; 417/418] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=2, min_child_weight=7, n_estimators=1400, reg_lambda=10, scale_pos_weight=850; balanced_accuracy: (train=0.814, test=0.770) roc_auc: (train=0.897, test=0.855) total time= 2.2min

# %%
xgb_classifier
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=0,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=6,
#               max_depth=2, max_leaves=0, min_child_weight=7, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=42, ...)

# %%
xgb_classifier.n_estimators, xgb_classifier.scale_pos_weight
# Out:
# (1000, 900)

# %% [markdown]
# ## Ensemble

# %%
y_pred_log = logistic_regression.predict(X_test)
y_pred_rf = random_forest.predict(X_test)

##How much does the predictions match 
(y_pred_rf == y_pred_log).sum() / (corrected_predicted_rf.shape)

# %%
from sklearn.ensemble import VotingClassifier as VC
eclf2 = VC(estimators=[ ('rf', random_forest), ('xgb', xgb_classifier), ('dt', decision_tree), ("lr", logistic_regression)],
        voting='soft',weights=[100, 100, 1, 1])
eclf2 = eclf2.fit(X_train, y_train)
get_df_metrics(eclf2)
