# %%
from dataAnalysis.DataAnalysis import DataAnalysis
import pandas as pd
from dataAnalysis.Constants import FEATURES, SEX_CATEGORY_COLUMN_NAME, FEATURES_IN_TABLE

data = pd.read_csv(r"extdata/sbcdata.csv", header=0)
data_analysis = DataAnalysis(data)
mimic_sbc = pd.read_csv("hosp_mimic_i.csv")
# Out:
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Training:
# Assessable data are 528101 cases and 1015074 CBCs
# Control data are 527038 cases and 1013548 CBCs
# Sepsis data are 1488 cases and 1526 CBCs
# $$$$$$$$$$$$$$$$$$$$
# Testing:
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 365794, Sepsis: 490
# Assessable data are 180494 cases and 366284 CBCs
# Control data are 180157 cases and 365794 CBCs
# Sepsis data are 472 cases and 490 CBCs
# /home/dwalke/git/sbc/dataAnalysis/data/Filter.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.data['Label'] = self.data['Diagnosis']
# Controls: 437629, Sepsis: 448
# Assessable data are 157922 cases and 438077 CBCs
# Control data are 180157 cases and 437629 CBCs
# Sepsis data are 438 cases and 448 CBCs

# %%
mimic_sbc = mimic_sbc.dropna(subset=FEATURES_IN_TABLE)
mimic_sbc.loc[:, SEX_CATEGORY_COLUMN_NAME] = mimic_sbc["Sex"] == "W"
mimic_sbc[SEX_CATEGORY_COLUMN_NAME] = mimic_sbc[SEX_CATEGORY_COLUMN_NAME].astype(int)

# %%
X_sbc = data_analysis.get_X_train() 
X_mimic = mimic_sbc.loc[:, FEATURES].values

X_test = data_analysis.get_X_test()
X_gw_test = data_analysis.get_X_gw()

y_sbc = data_analysis.get_y_train()
y_mimic = mimic_sbc.loc[:,"Label"].values
y_test = data_analysis.get_y_test()
y_gw_test = data_analysis.get_y_gw()

# %%
import numpy as np
X = np.concatenate((X_sbc, X_mimic), axis = 0)
y = np.concatenate((y_sbc, y_mimic), axis = 0)

# %%
import numpy as np
unique, counts = np.unique(y, return_counts=True)

# %%
from dataAnalysis.Metrics import Evaluation

evaluation = Evaluation(y_test, y_gw_test, X_test, X_gw_test)
# Out:
# /home/dwalke/.local/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
from sklearn.model_selection import GridSearchCV

def get_best_estimator(model, param_grid):
    grid = GridSearchCV(
    n_jobs=-1,
    cv=10,
    estimator=model,
    scoring='roc_auc',
    refit='auroc',
    return_train_score=True,
    param_grid=param_grid,
    verbose= 10
    )
    grid.fit(X, y)
    return grid.best_estimator_

# %%
counts[0]/ counts[1]
# Out:
# 42.12101505509855

# %%
from xgboost import XGBClassifier
param_grid = {
    'max_depth': [8, 10],
    'learning_rate': [0.1],
    'gamma': [0],
    'reg_lambda': [0],
    'scale_pos_weight': [i for i in range(5, 65, 5)],
    "min_child_weight": [2],
    "max_delta_step": [2],
    'n_estimators': [5, 10, 20, 50, 100, 200, 400, 500, 600, 700, 800, 900]
}
xgb_classifier = get_best_estimator(XGBClassifier(tree_method='gpu_hist', gpu_id = 2,
                                                        seed = 42), param_grid)
# Out:
# Fitting 10 folds for each of 288 candidates, totalling 2880 fits
# [CV 5/10; 1/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5
# [CV 5/10; 1/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5;, score=(train=0.819, test=0.729) total time=   8.5s
# [CV 7/10; 7/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35
# [CV 7/10; 7/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35;, score=(train=0.821, test=0.743) total time=   6.5s
# [CV 7/10; 8/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=40
# [CV 7/10; 8/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=40;, score=(train=0.821, test=0.744) total time=   8.7s
# [CV 4/10; 15/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=15
# [CV 4/10; 15/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=15;, score=(train=0.813, test=0.870) total time=   9.8s
# [CV 10/10; 21/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=45
# [CV 10/10; 21/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=45;, score=(train=0.828, test=0.729) total time=   8.8s
# [CV 4/10; 28/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20
# [CV 4/10; 28/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20;, score=(train=0.824, test=0.877) total time=  10.8s
# [CV 1/10; 34/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=50
# [CV 1/10; 34/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=50;, score=(train=0.822, test=0.908) total time=  11.8s
# [CV 8/10; 40/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=20
# [CV 8/10; 40/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=20;, score=(train=0.863, test=0.724) total time=  29.4s
# [CV 4/10; 46/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=50
# [CV 4/10; 46/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=50;, score=(train=0.849, test=0.895) total time=   6.7s
# [CV 4/10; 51/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=15
# [CV 4/10; 51/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=15;, score=(train=0.868, test=0.901) total time=  51.5s
# [CV 10/10; 56/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=40
# [CV 10/10; 56/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=40;, score=(train=0.882, test=0.734) total time=  37.6s
# [CV 5/10; 63/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=15
# [CV 5/10; 63/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=15;, score=(train=0.902, test=0.730) total time= 1.4min
# [CV 8/10; 69/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=45
# [CV 8/10; 69/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=45;, score=(train=0.903, test=0.708) total time= 1.0min
# [CV 7/10; 75/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=15
# [CV 7/10; 75/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=15;, score=(train=0.925, test=0.717) total time= 3.3min
# [CV 8/10; 81/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=45
# [CV 8/10; 81/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=45;, score=(train=0.925, test=0.692) total time= 3.1min
# [CV 3/10; 88/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=20
# [CV 3/10; 88/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=20;, score=(train=0.922, test=0.963) total time= 2.8min
# [CV 8/10; 94/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=50
# [CV 8/10; 94/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=50;, score=(train=0.932, test=0.689) total time= 2.3min
# [CV 2/10; 101/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=25
# [CV 2/10; 101/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=25;, score=(train=0.931, test=0.962) total time= 3.3min
# [CV 7/10; 107/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=55
# [CV 7/10; 107/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=55;, score=(train=0.938, test=0.696) total time= 2.7min
# [CV 1/10; 114/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=30
# [CV 1/10; 114/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=30;, score=(train=0.936, test=0.909) total time= 3.0min
# [CV 4/10; 120/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60
# [CV 4/10; 120/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60;, score=(train=0.936, test=0.888) total time= 3.5min
# [CV 10/10; 126/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=30
# [CV 10/10; 126/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=30;, score=(train=0.949, test=0.689) total time= 2.7min
# [CV 7/10; 133/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=5
# [CV 6/10; 1/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5
# [CV 6/10; 1/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5;, score=(train=0.817, test=0.748) total time=   9.1s
# [CV 8/10; 7/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35
# [CV 8/10; 7/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35;, score=(train=0.823, test=0.714) total time=   6.6s
# [CV 1/10; 9/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=45
# [CV 1/10; 9/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=45;, score=(train=0.805, test=0.890) total time=   5.2s
# [CV 9/10; 14/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=10
# [CV 9/10; 14/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=10;, score=(train=0.825, test=0.740) total time=  10.0s
# [CV 9/10; 21/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=45
# [CV 9/10; 21/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=45;, score=(train=0.826, test=0.736) total time=  10.0s
# [CV 5/10; 28/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20
# [CV 5/10; 28/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20;, score=(train=0.838, test=0.739) total time=  11.8s
# [CV 10/10; 34/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=50
# [CV 10/10; 34/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=50;, score=(train=0.837, test=0.733) total time=  11.4s
# [CV 1/10; 41/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=25
# [CV 1/10; 41/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=25;, score=(train=0.846, test=0.922) total time=  27.7s
# [CV 4/10; 47/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=55
# [CV 4/10; 47/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=55;, score=(train=0.848, test=0.895) total time=  22.1s
# [CV 7/10; 53/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=25
# [CV 7/10; 53/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=25;, score=(train=0.881, test=0.746) total time=  42.0s
# [CV 6/10; 59/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=55
# [CV 6/10; 59/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=55;, score=(train=0.881, test=0.750) total time=  50.6s
# [CV 5/10; 66/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=30
# [CV 5/10; 66/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=30;, score=(train=0.903, test=0.726) total time= 1.6min
# [CV 6/10; 72/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=60
# [CV 6/10; 72/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=60;, score=(train=0.901, test=0.729) total time= 1.6min
# [CV 2/10; 79/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35
# [CV 2/10; 79/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35;, score=(train=0.914, test=0.966) total time= 2.7min
# [CV 8/10; 84/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60
# [CV 8/10; 84/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60;, score=(train=0.925, test=0.693) total time= 3.2min
# [CV 4/10; 91/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35
# [CV 4/10; 91/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35;, score=(train=0.926, test=0.891) total time= 2.0min
# [CV 6/10; 96/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=60
# [CV 6/10; 96/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=60;, score=(train=0.932, test=0.695) total time= 2.3min
# [CV 1/10; 101/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=25
# [CV 1/10; 101/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=25;, score=(train=0.930, test=0.914) total time= 3.3min
# [CV 4/10; 107/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=55
# [CV 4/10; 107/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=55;, score=(train=0.930, test=0.892) total time= 2.4min
# [CV 9/10; 113/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=25
# [CV 9/10; 113/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=25;, score=(train=0.945, test=0.703) total time= 3.4min
# [CV 2/10; 120/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60
# [CV 2/10; 120/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=60;, score=(train=0.935, test=0.957) total time= 3.4min
# [CV 8/10; 126/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=30
# [CV 8/10; 126/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=30;, score=(train=0.951, test=0.676) total time= 2.8min
# [CV 4/10; 133/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=5
# [CV 8/10; 3/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=15
# [CV 8/10; 3/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=15;, score=(train=0.822, test=0.714) total time=   8.2s
# [CV 6/10; 7/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35
# [CV 6/10; 7/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35;, score=(train=0.820, test=0.749) total time=   6.6s
# [CV 6/10; 8/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=40
# [CV 6/10; 8/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=40;, score=(train=0.820, test=0.748) total time=   7.3s
# [CV 2/10; 15/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=15
# [CV 2/10; 15/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=15;, score=(train=0.810, test=0.907) total time=   6.7s
# [CV 8/10; 19/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=35
# [CV 8/10; 19/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=35;, score=(train=0.828, test=0.717) total time=   8.9s
# [CV 1/10; 26/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=10
# [CV 1/10; 26/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=10;, score=(train=0.821, test=0.898) total time=  10.4s
# [CV 8/10; 32/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=40
# [CV 8/10; 32/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=40;, score=(train=0.839, test=0.720) total time=   9.6s
# [CV 5/10; 39/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=15
# [CV 5/10; 39/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=15;, score=(train=0.860, test=0.743) total time=  26.1s
# [CV 10/10; 45/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=45
# [CV 10/10; 45/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=45;, score=(train=0.862, test=0.737) total time=  11.7s
# [CV 6/10; 52/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=20
# [CV 6/10; 52/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=20;, score=(train=0.880, test=0.753) total time=  52.3s
# [CV 9/10; 58/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=50
# [CV 9/10; 58/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=50;, score=(train=0.880, test=0.743) total time=  48.0s
# [CV 1/10; 65/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=25
# [CV 1/10; 65/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=25;, score=(train=0.889, test=0.930) total time= 1.6min
# [CV 3/10; 71/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=55
# [CV 3/10; 71/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=55;, score=(train=0.888, test=0.968) total time= 1.6min
# [CV 4/10; 78/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30
# [CV 4/10; 78/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30;, score=(train=0.917, test=0.893) total time= 2.8min
# [CV 2/10; 85/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=5
# [CV 2/10; 85/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=5;, score=(train=0.920, test=0.963) total time= 3.8min
# [CV 2/10; 92/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40
# [CV 2/10; 92/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40;, score=(train=0.922, test=0.963) total time= 1.9min
# [CV 9/10; 97/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5
# [CV 9/10; 97/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5;, score=(train=0.938, test=0.718) total time= 2.9min
# [CV 6/10; 103/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=35
# [CV 6/10; 103/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=35;, score=(train=0.940, test=0.693) total time= 2.3min
# [CV 2/10; 110/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10
# [CV 2/10; 110/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10;, score=(train=0.938, test=0.962) total time= 4.1min
# [CV 8/10; 116/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40
# [CV 8/10; 116/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40;, score=(train=0.944, test=0.677) total time= 1.2min
# [CV 2/10; 123/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15
# [CV 2/10; 123/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15;, score=(train=0.944, test=0.961) total time= 5.0min
# [CV 2/10; 129/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45
# [CV 2/10; 129/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45;, score=(train=0.942, test=0.955) total time= 1.4min
# [CV 8/10; 135/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15
# [CV 1/10; 1/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5
# [CV 1/10; 1/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5;, score=(train=0.804, test=0.886) total time=   9.1s
# [CV 5/10; 7/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35
# [CV 5/10; 7/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35;, score=(train=0.822, test=0.732) total time=   6.5s
# [CV 3/10; 8/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=40
# [CV 3/10; 8/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=40;, score=(train=0.803, test=0.909) total time=   5.9s
# [CV 3/10; 14/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=10
# [CV 3/10; 14/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=10;, score=(train=0.808, test=0.909) total time=  10.2s
# [CV 4/10; 21/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=45
# [CV 4/10; 21/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=45;, score=(train=0.813, test=0.871) total time=   9.7s
# [CV 3/10; 28/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20
# [CV 3/10; 28/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20;, score=(train=0.820, test=0.920) total time=  11.5s
# [CV 6/10; 34/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=50
# [CV 6/10; 34/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=50;, score=(train=0.836, test=0.754) total time=  11.7s
# [CV 2/10; 41/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=25
# [CV 2/10; 41/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=25;, score=(train=0.844, test=0.940) total time=  28.6s
# [CV 6/10; 47/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=55
# [CV 6/10; 47/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=55;, score=(train=0.861, test=0.755) total time=  24.1s
# [CV 9/10; 53/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=25
# [CV 9/10; 53/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=25;, score=(train=0.881, test=0.746) total time=  41.1s
# [CV 10/10; 60/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60
# [CV 10/10; 60/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60;, score=(train=0.881, test=0.734) total time=  49.6s
# [CV 3/10; 67/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35
# [CV 3/10; 67/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35;, score=(train=0.886, test=0.966) total time= 1.6min
# [CV 7/10; 73/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5
# [CV 7/10; 73/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5;, score=(train=0.923, test=0.722) total time= 3.2min
# [CV 1/10; 80/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40
# [CV 1/10; 80/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40;, score=(train=0.913, test=0.918) total time= 2.5min
# [CV 5/10; 86/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10
# [CV 5/10; 86/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10;, score=(train=0.934, test=0.713) total time= 2.9min
# [CV 9/10; 92/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40
# [CV 9/10; 92/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40;, score=(train=0.932, test=0.714) total time= 1.7min
# [CV 3/10; 99/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15
# [CV 3/10; 99/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15;, score=(train=0.930, test=0.960) total time= 3.5min
# [CV 7/10; 105/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=45
# [CV 7/10; 105/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=45;, score=(train=0.938, test=0.698) total time= 1.8min
# [CV 9/10; 111/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15
# [CV 9/10; 111/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15;, score=(train=0.945, test=0.707) total time= 4.3min
# [CV 10/10; 117/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45
# [CV 10/10; 117/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45;, score=(train=0.944, test=0.692) total time= 1.1min
# [CV 4/10; 124/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=20
# [CV 4/10; 124/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=20;, score=(train=0.944, test=0.889) total time= 4.7min
# [CV 6/10; 130/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50
# [CV 6/10; 130/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50;, score=(train=0.949, test=0.682) total time= 1.9min
# [CV 1/10; 137/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25
# [CV 4/10; 7/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35
# [CV 4/10; 7/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=35;, score=(train=0.807, test=0.866) total time=  19.2s
# [CV 7/10; 9/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=45
# [CV 7/10; 9/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=45;, score=(train=0.820, test=0.744) total time=   8.0s
# [CV 9/10; 15/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=15
# [CV 9/10; 15/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=15;, score=(train=0.826, test=0.739) total time=   7.8s
# [CV 6/10; 22/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=50
# [CV 6/10; 22/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=50;, score=(train=0.826, test=0.750) total time=   9.5s
# [CV 10/10; 28/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20
# [CV 10/10; 28/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=20;, score=(train=0.837, test=0.734) total time=  10.3s
# [CV 4/10; 35/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=55
# [CV 4/10; 35/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=55;, score=(train=0.824, test=0.881) total time=  11.2s
# [CV 7/10; 41/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=25
# [CV 7/10; 41/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=25;, score=(train=0.860, test=0.752) total time=  28.1s
# [CV 3/10; 48/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=60
# [CV 3/10; 48/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=60;, score=(train=0.843, test=0.949) total time=  30.3s
# [CV 1/10; 55/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=35
# [CV 1/10; 55/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=35;, score=(train=0.869, test=0.928) total time=  36.8s
# [CV 7/10; 61/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=5
# [CV 7/10; 61/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=5;, score=(train=0.898, test=0.740) total time= 1.3min
# [CV 10/10; 67/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35
# [CV 10/10; 67/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35;, score=(train=0.903, test=0.726) total time= 1.3min
# [CV 3/10; 74/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=10
# [CV 3/10; 74/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=10;, score=(train=0.910, test=0.969) total time= 3.3min
# [CV 8/10; 80/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40
# [CV 8/10; 80/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40;, score=(train=0.925, test=0.695) total time= 2.7min
# [CV 2/10; 87/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15
# [CV 2/10; 87/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15;, score=(train=0.923, test=0.964) total time= 2.7min
# [CV 6/10; 93/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45
# [CV 6/10; 93/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45;, score=(train=0.933, test=0.695) total time= 2.0min
# [CV 2/10; 100/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=20
# [CV 2/10; 100/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=20;, score=(train=0.931, test=0.963) total time= 3.6min
# [CV 7/10; 106/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50
# [CV 7/10; 106/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50;, score=(train=0.939, test=0.701) total time= 1.8min
# [CV 2/10; 113/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=25
# [CV 2/10; 113/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=25;, score=(train=0.937, test=0.960) total time= 3.9min
# [CV 4/10; 119/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55
# [CV 4/10; 119/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55;, score=(train=0.936, test=0.890) total time= 2.3min
# [CV 4/10; 125/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25
# [CV 4/10; 125/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25;, score=(train=0.944, test=0.890) total time= 4.2min
# [CV 10/10; 131/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=55
# [CV 10/10; 131/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=55;, score=(train=0.947, test=0.688) total time= 4.2min
# [CV 7/10; 138/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30
# [CV 7/10; 138/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30;, score=(train=0.955, test=0.686) total time= 2.5min
# [CV 1/10; 145/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5
# [CV 2/10; 1/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5
# [CV 2/10; 1/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=5;, score=(train=0.801, test=0.899) total time=  21.4s
# [CV 10/10; 9/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=45
# [CV 10/10; 9/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=5, reg_lambda=0, scale_pos_weight=45;, score=(train=0.821, test=0.727) total time=   8.8s
# [CV 6/10; 16/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=20
# [CV 6/10; 16/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=20;, score=(train=0.826, test=0.752) total time=   9.6s
# [CV 10/10; 22/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=50
# [CV 10/10; 22/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=10, reg_lambda=0, scale_pos_weight=50;, score=(train=0.827, test=0.731) total time=   9.5s
# [CV 7/10; 29/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=25
# [CV 7/10; 29/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=25;, score=(train=0.836, test=0.750) total time=  11.0s
# [CV 2/10; 36/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=60
# [CV 2/10; 36/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=20, reg_lambda=0, scale_pos_weight=60;, score=(train=0.821, test=0.925) total time=   9.2s
# [CV 8/10; 42/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=30
# [CV 8/10; 42/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=30;, score=(train=0.863, test=0.723) total time=  26.1s
# [CV 3/10; 49/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=5
# [CV 3/10; 49/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=5;, score=(train=0.860, test=0.952) total time=  52.5s
# [CV 6/10; 55/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=35
# [CV 6/10; 55/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=35;, score=(train=0.881, test=0.749) total time=  22.5s
# [CV 6/10; 62/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=10
# [CV 6/10; 62/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=10;, score=(train=0.901, test=0.742) total time= 1.4min
# [CV 8/10; 68/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=40
# [CV 8/10; 68/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=40;, score=(train=0.903, test=0.712) total time= 1.1min
# [CV 8/10; 74/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=10
# [CV 8/10; 74/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=10;, score=(train=0.926, test=0.698) total time= 3.3min
# [CV 10/10; 80/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40
# [CV 10/10; 80/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40;, score=(train=0.925, test=0.709) total time= 2.8min
# [CV 3/10; 87/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15
# [CV 3/10; 87/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15;, score=(train=0.922, test=0.962) total time= 2.7min
# [CV 4/10; 93/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45
# [CV 4/10; 93/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45;, score=(train=0.924, test=0.890) total time= 1.9min
# [CV 7/10; 99/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15
# [CV 7/10; 99/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15;, score=(train=0.939, test=0.704) total time= 3.6min
# [CV 6/10; 106/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50
# [CV 6/10; 106/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50;, score=(train=0.938, test=0.692) total time= 1.7min
# [CV 7/10; 112/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=20
# [CV 7/10; 112/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=20;, score=(train=0.947, test=0.695) total time= 4.0min
# [CV 3/10; 119/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55
# [CV 3/10; 119/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55;, score=(train=0.936, test=0.955) total time= 2.5min
# [CV 8/10; 125/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25
# [CV 8/10; 125/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25;, score=(train=0.950, test=0.677) total time= 3.9min
# [CV 4/10; 132/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=60
# ...
# [CV 3/10; 194/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=10
# [CV 3/10; 194/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=10;, score=(train=0.902, test=0.958) total time= 1.2min
# [CV 6/10; 200/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=40
# [CV 6/10; 200/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=40;, score=(train=0.916, test=0.727) total time= 1.6min
# [CV 10/10; 206/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=10
# [CV 10/10; 206/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=10;, score=(train=0.939, test=0.715) total time= 3.0min
# [CV 2/10; 213/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=45
# [CV 2/10; 213/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=45;, score=(train=0.931, test=0.961) total time= 2.5min
# [CV 6/10; 219/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=15
# [CV 6/10; 219/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=15;, score=(train=0.965, test=0.682) total time= 5.4min
# [CV 7/10; 225/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=45
# [CV 7/10; 225/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=45;, score=(train=0.961, test=0.682) total time= 1.3min
# [CV 1/10; 232/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=20
# [CV 1/10; 232/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=20;, score=(train=0.967, test=0.901) total time= 5.0min
# [CV 2/10; 238/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=50
# [CV 2/10; 238/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=50;, score=(train=0.965, test=0.943) total time= 5.6min
# [CV 10/10; 243/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15
# [CV 10/10; 243/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15;, score=(train=0.976, test=0.673) total time= 2.3min
# [CV 2/10; 250/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50
# [CV 2/10; 250/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50;, score=(train=0.971, test=0.937) total time= 5.0min
# [CV 6/10; 256/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=20
# [CV 6/10; 256/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=20;, score=(train=0.980, test=0.647) total time= 7.3min
# [CV 9/10; 262/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50
# [CV 9/10; 262/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50;, score=(train=0.976, test=0.668) total time= 7.9min
# [CV 3/10; 269/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25
# [CV 3/10; 269/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25;, score=(train=0.981, test=0.941) total time= 6.4min
# [CV 7/10; 275/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=55
# [CV 7/10; 275/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=55;, score=(train=0.980, test=0.654) total time= 9.0min
# [CV 10/10; 281/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25
# [CV 10/10; 281/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25;, score=(train=0.985, test=0.649) total time=11.3min
# [CV 5/10; 288/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60
# [CV 2/10; 220/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=20;, score=(train=0.960, test=0.952) total time= 5.2min
# [CV 3/10; 227/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=55
# [CV 3/10; 227/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=55;, score=(train=0.954, test=0.950) total time= 4.8min
# [CV 8/10; 233/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=25
# [CV 8/10; 233/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=25;, score=(train=0.971, test=0.664) total time= 1.5min
# [CV 4/10; 240/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=60
# [CV 4/10; 240/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=60;, score=(train=0.964, test=0.881) total time= 5.6min
# [CV 9/10; 246/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=30
# [CV 9/10; 246/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=30;, score=(train=0.974, test=0.679) total time= 5.3min
# [CV 3/10; 253/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=5
# [CV 3/10; 253/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=5;, score=(train=0.978, test=0.952) total time= 3.3min
# [CV 5/10; 259/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35
# [CV 5/10; 259/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35;, score=(train=0.979, test=0.672) total time= 5.5min
# [CV 8/10; 265/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=5
# [CV 8/10; 265/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=5;, score=(train=0.985, test=0.662) total time=10.4min
# [CV 3/10; 272/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=40
# [CV 3/10; 272/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=40;, score=(train=0.978, test=0.936) total time=10.6min
# [CV 9/10; 278/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=10
# [CV 9/10; 278/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=10;, score=(train=0.987, test=0.671) total time=10.9min
# [CV 3/10; 285/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45
# [CV 3/10; 285/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45;, score=(train=0.981, test=0.926) total time= 5.0min
# [CV 8/10; 135/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15;, score=(train=0.956, test=0.673) total time= 5.5min
# [CV 6/10; 142/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 6/10; 142/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.952, test=0.677) total time= 5.6min
# [CV 10/10; 192/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=60
# [CV 10/10; 192/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=60;, score=(train=0.893, test=0.728) total time=  14.0s
# [CV 1/10; 197/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=25
# [CV 1/10; 197/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=25;, score=(train=0.904, test=0.925) total time= 1.3min
# [CV 2/10; 203/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=55
# [CV 2/10; 203/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=55;, score=(train=0.904, test=0.962) total time= 1.7min
# [CV 1/10; 209/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=25
# [CV 1/10; 209/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=25;, score=(train=0.930, test=0.919) total time= 3.2min
# [CV 4/10; 215/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=55
# [CV 4/10; 215/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=55;, score=(train=0.933, test=0.893) total time= 3.3min
# [CV 5/10; 222/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30
# [CV 5/10; 222/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30;, score=(train=0.963, test=0.688) total time= 5.0min
# [CV 10/10; 228/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60
# [CV 10/10; 228/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60;, score=(train=0.961, test=0.679) total time= 5.3min
# [CV 5/10; 235/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35
# [CV 5/10; 235/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35;, score=(train=0.970, test=0.681) total time= 1.9min
# [CV 3/10; 241/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5
# [CV 3/10; 241/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5;, score=(train=0.973, test=0.954) total time= 5.4min
# [CV 7/10; 247/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=35
# [CV 7/10; 247/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=35;, score=(train=0.974, test=0.670) total time= 5.5min
# [CV 1/10; 254/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10
# [CV 1/10; 254/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10;, score=(train=0.977, test=0.902) total time= 3.5min
# [CV 5/10; 260/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40
# [CV 5/10; 260/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40;, score=(train=0.978, test=0.669) total time= 4.1min
# [CV 5/10; 266/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10
# [CV 5/10; 266/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10;, score=(train=0.984, test=0.682) total time=10.4min
# [CV 9/10; 272/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=40
# [CV 9/10; 272/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=40;, score=(train=0.981, test=0.667) total time=10.6min
# [CV 1/10; 279/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15
# [CV 1/10; 279/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15;, score=(train=0.984, test=0.894) total time=11.1min
# [CV 4/10; 285/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45
# [CV 4/10; 285/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45;, score=(train=0.983, test=0.870) total time= 5.8min

# %%
xgb_classifier.scale_pos_weight, xgb_classifier.reg_lambda,xgb_classifier.max_depth, xgb_classifier.n_estimators
# Out:
# (15, 0, 8, 100)

# %%
from xgboost import XGBClassifier
xgb_classifier_model = XGBClassifier(tree_method='gpu_hist', 
                           scale_pos_weight = 15,
                           n_estimators=100,
                           max_depth=8,
                           eta=0.1,
                                     gamma=0,
                                     reg_lambda=0,
                           min_child_weight = 2,
                           max_delta_step= 2,
                           sampling_method= "uniform")
xgb_classifier_model.fit(X, y)
print(evaluation.get_df_metrics(xgb_classifier_model))
evaluation.plot_confusion_matrix(xgb_classifier_model)
# Out:
#          Name       MCC  F1-Micro  F1-Macro  F1-Binary     AUROC     AUPRC
# 0     Leipzig  0.027532  0.993311  0.510274   0.023904  0.830920  0.008358
# 1  Greifswald  0.018098  0.986475  0.502269   0.011347  0.746562  0.003743
# [CV 7/10; 285/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45
# [CV 7/10; 285/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45;, score=(train=0.983, test=0.649) total time= 6.9min
# [CV 8/10; 144/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60;, score=(train=0.952, test=0.670) total time= 6.5min
# [CV 6/10; 199/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=35
# [CV 6/10; 199/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=35;, score=(train=0.916, test=0.733) total time= 1.5min
# [CV 1/10; 206/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=10
# [CV 1/10; 206/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=10;, score=(train=0.926, test=0.922) total time= 3.0min
# [CV 5/10; 212/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=40
# [CV 5/10; 212/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=40;, score=(train=0.939, test=0.711) total time= 1.7min
# [CV 9/10; 218/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=10
# [CV 9/10; 218/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=10;, score=(train=0.964, test=0.703) total time= 5.6min
# [CV 5/10; 225/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=45
# [CV 5/10; 225/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=45;, score=(train=0.963, test=0.691) total time= 1.3min
# [CV 10/10; 231/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15
# [CV 10/10; 231/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15;, score=(train=0.971, test=0.678) total time= 5.0min
# [CV 1/10; 239/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=55
# [CV 1/10; 239/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=55;, score=(train=0.962, test=0.891) total time= 5.9min
# [CV 8/10; 245/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=25
# [CV 8/10; 245/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=25;, score=(train=0.976, test=0.658) total time= 4.9min
# [CV 8/10; 252/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=60
# [CV 8/10; 252/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=60;, score=(train=0.973, test=0.656) total time= 3.6min
# [CV 4/10; 259/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35
# [CV 4/10; 259/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35;, score=(train=0.976, test=0.877) total time= 6.2min
# [CV 9/10; 265/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=5
# [CV 9/10; 265/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=5;, score=(train=0.985, test=0.687) total time=10.4min
# [CV 7/10; 272/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=40
# [CV 7/10; 272/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=40;, score=(train=0.982, test=0.657) total time=10.7min
# [CV 5/10; 279/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15
# [CV 5/10; 279/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15;, score=(train=0.988, test=0.669) total time=11.4min
# [CV 1/10; 286/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 1/10; 286/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.981, test=0.877) total time= 7.0min
# [CV 1/10; 248/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40;, score=(train=0.970, test=0.892) total time= 5.8min
# [CV 2/10; 254/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10
# [CV 2/10; 254/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10;, score=(train=0.979, test=0.950) total time= 4.1min
# [CV 6/10; 260/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40
# [CV 6/10; 260/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40;, score=(train=0.979, test=0.641) total time= 2.6min
# [CV 10/10; 266/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10
# [CV 10/10; 266/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10;, score=(train=0.985, test=0.666) total time=10.4min
# [CV 5/10; 273/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45
# [CV 5/10; 273/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45;, score=(train=0.981, test=0.668) total time=10.7min
# [CV 6/10; 279/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15
# [CV 6/10; 279/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15;, score=(train=0.987, test=0.645) total time=11.4min
# [CV 9/10; 285/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45
# [CV 9/10; 285/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45;, score=(train=0.983, test=0.662) total time= 6.9min
# [CV 8/10; 143/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=55;, score=(train=0.954, test=0.668) total time= 6.3min
# [CV 7/10; 198/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=30
# [CV 7/10; 198/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=30;, score=(train=0.916, test=0.731) total time= 1.4min
# [CV 10/10; 204/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60
# [CV 10/10; 204/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60;, score=(train=0.916, test=0.720) total time= 1.5min
# [CV 4/10; 211/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35
# [CV 4/10; 211/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35;, score=(train=0.933, test=0.894) total time= 2.7min
# [CV 8/10; 217/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5
# [CV 8/10; 217/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5;, score=(train=0.963, test=0.686) total time= 5.5min
# [CV 10/10; 223/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35
# [CV 10/10; 223/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35;, score=(train=0.964, test=0.680) total time=  53.3s
# [CV 5/10; 230/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10
# [CV 5/10; 230/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10;, score=(train=0.972, test=0.695) total time= 6.1min
# [CV 10/10; 236/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40
# [CV 10/10; 236/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40;, score=(train=0.968, test=0.674) total time= 4.5min
# [CV 5/10; 243/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15
# [CV 5/10; 243/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15;, score=(train=0.978, test=0.682) total time= 2.6min
# [CV 1/10; 250/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50
# [CV 1/10; 250/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50;, score=(train=0.969, test=0.889) total time= 4.5min
# [CV 7/10; 253/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=5
# [CV 7/10; 253/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=5;, score=(train=0.981, test=0.678) total time= 2.8min
# [CV 8/10; 259/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35
# [CV 8/10; 259/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35;, score=(train=0.979, test=0.648) total time= 5.3min
# [CV 7/10; 266/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10
# [CV 7/10; 266/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10;, score=(train=0.984, test=0.665) total time=10.5min
# [CV 2/10; 273/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45
# [CV 2/10; 273/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45;, score=(train=0.979, test=0.932) total time=10.7min
# [CV 8/10; 279/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15
# [CV 8/10; 279/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15;, score=(train=0.986, test=0.648) total time=11.5min
# [CV 2/10; 286/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 2/10; 286/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.982, test=0.926) total time= 7.3min
# [CV 2/10; 216/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=60
# [CV 2/10; 216/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=60;, score=(train=0.930, test=0.962) total time= 3.3min
# [CV 4/10; 222/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30
# [CV 4/10; 222/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30;, score=(train=0.957, test=0.883) total time= 5.0min
# [CV 5/10; 229/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=5
# [CV 5/10; 229/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=5;, score=(train=0.971, test=0.696) total time= 6.1min
# [CV 8/10; 235/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35
# [CV 8/10; 235/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35;, score=(train=0.970, test=0.660) total time= 1.6min
# [CV 2/10; 242/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=10
# [CV 2/10; 242/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=10;, score=(train=0.974, test=0.952) total time= 4.6min
# [CV 8/10; 248/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40
# [CV 8/10; 248/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40;, score=(train=0.975, test=0.654) total time= 5.7min
# [CV 1/10; 255/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15
# [CV 1/10; 255/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15;, score=(train=0.977, test=0.898) total time= 6.0min
# [CV 6/10; 261/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45
# [CV 6/10; 261/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45;, score=(train=0.979, test=0.646) total time= 1.7min
# [CV 10/10; 267/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15
# [CV 10/10; 267/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15;, score=(train=0.984, test=0.661) total time= 9.8min
# [CV 3/10; 274/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50
# [CV 3/10; 274/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50;, score=(train=0.978, test=0.934) total time=10.7min
# [CV 1/10; 280/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20
# [CV 1/10; 280/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20;, score=(train=0.983, test=0.890) total time=11.6min
# [CV 5/10; 286/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 5/10; 286/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.983, test=0.665) total time= 7.2min
# [CV 10/10; 194/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=10;, score=(train=0.916, test=0.728) total time= 1.3min
# [CV 5/10; 201/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=45
# [CV 5/10; 201/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=45;, score=(train=0.918, test=0.722) total time= 1.7min
# [CV 9/10; 207/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=15
# [CV 9/10; 207/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=15;, score=(train=0.940, test=0.723) total time= 3.1min
# [CV 4/10; 214/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=50
# [CV 4/10; 214/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=50;, score=(train=0.932, test=0.893) total time= 3.2min
# [CV 9/10; 220/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=20
# [CV 9/10; 220/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=20;, score=(train=0.963, test=0.701) total time= 5.0min
# [CV 7/10; 227/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=55
# [CV 7/10; 227/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=55;, score=(train=0.961, test=0.681) total time= 5.0min
# [CV 10/10; 233/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=25
# [CV 10/10; 233/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=25;, score=(train=0.969, test=0.674) total time= 1.5min
# [CV 6/10; 240/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=60
# [CV 6/10; 240/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=60;, score=(train=0.969, test=0.654) total time= 5.5min
# [CV 10/10; 246/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=30
# [CV 10/10; 246/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=30;, score=(train=0.975, test=0.663) total time= 5.4min
# [CV 2/10; 253/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=5
# [CV 2/10; 253/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=5;, score=(train=0.978, test=0.955) total time= 3.6min
# [CV 10/10; 259/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35
# [CV 10/10; 259/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=35;, score=(train=0.980, test=0.659) total time= 5.1min
# [CV 6/10; 266/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10
# [CV 6/10; 266/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=10;, score=(train=0.984, test=0.653) total time=10.5min
# [CV 4/10; 273/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45
# [CV 4/10; 273/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45;, score=(train=0.980, test=0.871) total time=10.7min
# [CV 10/10; 279/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15
# [CV 10/10; 279/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15;, score=(train=0.986, test=0.656) total time=11.5min
# [CV 4/10; 286/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 4/10; 286/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.981, test=0.868) total time= 7.3min
# [CV 2/10; 279/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15
# [CV 2/10; 279/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=15;, score=(train=0.985, test=0.943) total time=11.5min
# [CV 10/10; 285/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45
# [CV 10/10; 285/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=45;, score=(train=0.983, test=0.647) total time= 7.2min
# [CV 2/10; 191/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=55;, score=(train=0.880, test=0.953) total time=  34.6s
# [CV 9/10; 194/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=10
# [CV 9/10; 194/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=10;, score=(train=0.914, test=0.738) total time= 1.3min
# [CV 10/10; 200/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=40
# [CV 10/10; 200/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=40;, score=(train=0.914, test=0.723) total time= 1.7min
# [CV 5/10; 207/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=15
# [CV 5/10; 207/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=15;, score=(train=0.941, test=0.713) total time= 3.2min
# [CV 1/10; 214/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=50
# [CV 1/10; 214/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=50;, score=(train=0.930, test=0.915) total time= 3.1min
# [CV 5/10; 220/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=20
# [CV 5/10; 220/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=20;, score=(train=0.965, test=0.696) total time= 5.1min
# [CV 1/10; 228/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60
# [CV 1/10; 228/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60;, score=(train=0.955, test=0.899) total time= 5.2min
# [CV 6/10; 234/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=30
# [CV 6/10; 234/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=30;, score=(train=0.971, test=0.660) total time= 2.2min
# [CV 7/10; 241/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5
# [CV 7/10; 241/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5;, score=(train=0.976, test=0.685) total time= 5.4min
# [CV 2/10; 248/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40
# [CV 2/10; 248/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40;, score=(train=0.971, test=0.942) total time= 5.7min
# [CV 5/10; 254/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10
# [CV 5/10; 254/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10;, score=(train=0.981, test=0.687) total time= 5.4min
# [CV 1/10; 261/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45
# [CV 1/10; 261/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45;, score=(train=0.974, test=0.885) total time= 1.5min
# [CV 5/10; 267/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15
# [CV 5/10; 267/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15;, score=(train=0.985, test=0.672) total time=10.3min
# [CV 10/10; 273/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45
# [CV 10/10; 273/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45;, score=(train=0.980, test=0.652) total time=10.6min
# [CV 2/10; 280/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20
# [CV 2/10; 280/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20;, score=(train=0.984, test=0.939) total time=11.6min
# [CV 7/10; 286/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 7/10; 286/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.983, test=0.649) total time= 7.3min
# [CV 1/10; 142/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.945, test=0.900) total time= 5.3min
# [CV 2/10; 188/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=40
# [CV 2/10; 188/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=40;, score=(train=0.881, test=0.951) total time=   8.1s
# [CV 10/10; 191/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=55
# [CV 10/10; 191/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=50, reg_lambda=0, scale_pos_weight=55;, score=(train=0.892, test=0.726) total time=  32.9s
# [CV 10/10; 195/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=15
# [CV 10/10; 195/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=15;, score=(train=0.915, test=0.728) total time= 1.3min
# [CV 6/10; 202/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=50
# [CV 6/10; 202/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=50;, score=(train=0.916, test=0.727) total time= 1.7min
# [CV 5/10; 209/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=25
# [CV 5/10; 209/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=25;, score=(train=0.941, test=0.711) total time= 3.2min
# [CV 8/10; 215/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=55
# [CV 8/10; 215/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=55;, score=(train=0.942, test=0.690) total time= 3.3min
# [CV 1/10; 222/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30
# [CV 1/10; 222/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=30;, score=(train=0.957, test=0.904) total time= 5.0min
# [CV 7/10; 228/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60
# [CV 7/10; 228/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60;, score=(train=0.961, test=0.680) total time= 5.3min
# [CV 1/10; 235/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35
# [CV 1/10; 235/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35;, score=(train=0.963, test=0.897) total time= 2.2min
# [CV 5/10; 241/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5
# [CV 5/10; 241/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5;, score=(train=0.977, test=0.691) total time= 5.3min
# [CV 5/10; 247/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=35
# [CV 5/10; 247/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=35;, score=(train=0.975, test=0.676) total time= 5.8min
# [CV 4/10; 254/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10
# [CV 4/10; 254/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10;, score=(train=0.980, test=0.882) total time= 5.3min
# [CV 10/10; 260/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40
# [CV 10/10; 260/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=40;, score=(train=0.977, test=0.658) total time= 1.6min
# [CV 4/10; 267/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15
# [CV 4/10; 267/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15;, score=(train=0.982, test=0.878) total time=10.4min
# [CV 8/10; 273/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45
# [CV 8/10; 273/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45;, score=(train=0.981, test=0.646) total time=10.7min
# [CV 4/10; 280/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20
# [CV 4/10; 280/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20;, score=(train=0.985, test=0.874) total time=11.6min
# [CV 9/10; 286/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 9/10; 286/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.982, test=0.658) total time= 7.3min
# [CV 6/10; 221/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=25
# [CV 6/10; 221/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=25;, score=(train=0.964, test=0.675) total time= 5.0min
# [CV 2/10; 228/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60
# [CV 2/10; 228/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=60;, score=(train=0.956, test=0.948) total time= 5.3min
# [CV 4/10; 235/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35
# [CV 4/10; 235/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=35;, score=(train=0.966, test=0.882) total time= 2.1min
# [CV 9/10; 241/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5
# [CV 9/10; 241/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=5;, score=(train=0.977, test=0.697) total time= 5.4min
# [CV 4/10; 248/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40
# [CV 4/10; 248/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40;, score=(train=0.972, test=0.877) total time= 5.8min
# [CV 9/10; 254/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10
# [CV 9/10; 254/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=10;, score=(train=0.980, test=0.681) total time= 5.7min
# [CV 4/10; 261/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45
# [CV 4/10; 261/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45;, score=(train=0.976, test=0.875) total time= 1.5min
# [CV 9/10; 267/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15
# [CV 9/10; 267/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=15;, score=(train=0.983, test=0.675) total time=10.0min
# [CV 9/10; 273/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45
# [CV 9/10; 273/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=45;, score=(train=0.980, test=0.667) total time=10.6min
# [CV 5/10; 280/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20
# [CV 5/10; 280/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20;, score=(train=0.986, test=0.669) total time=11.6min
# [CV 8/10; 286/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50
# [CV 8/10; 286/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=50;, score=(train=0.983, test=0.641) total time= 7.3min
# [CV 1/10; 137/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25;, score=(train=0.947, test=0.905) total time= 4.4min
# [CV 4/10; 143/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=55
# [CV 4/10; 143/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=8, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=55;, score=(train=0.946, test=0.887) total time= 6.3min
# [CV 3/10; 198/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=30
# [CV 3/10; 198/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=30;, score=(train=0.907, test=0.962) total time= 1.4min
# [CV 7/10; 204/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60
# [CV 7/10; 204/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60;, score=(train=0.915, test=0.729) total time= 1.4min
# [CV 1/10; 211/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35
# [CV 1/10; 211/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35;, score=(train=0.930, test=0.918) total time= 3.0min
# [CV 1/10; 217/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5
# [CV 1/10; 217/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5;, score=(train=0.955, test=0.917) total time= 5.4min
# [CV 6/10; 223/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35
# [CV 6/10; 223/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35;, score=(train=0.964, test=0.672) total time=  53.5s
# [CV 4/10; 230/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10
# [CV 4/10; 230/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10;, score=(train=0.969, test=0.886) total time= 6.2min
# [CV 1/10; 236/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40
# [CV 1/10; 236/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=40;, score=(train=0.963, test=0.896) total time= 2.3min
# [CV 4/10; 242/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=10
# [CV 4/10; 242/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=10;, score=(train=0.975, test=0.884) total time= 4.3min
# [CV 7/10; 248/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40
# [CV 7/10; 248/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=40;, score=(train=0.975, test=0.666) total time= 5.7min
# [CV 3/10; 255/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15
# [CV 3/10; 255/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15;, score=(train=0.978, test=0.947) total time= 6.2min
# [CV 7/10; 261/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45
# [CV 7/10; 261/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=45;, score=(train=0.977, test=0.660) total time= 2.7min
# [CV 1/10; 268/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=20
# [CV 1/10; 268/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=20;, score=(train=0.981, test=0.892) total time= 9.4min
# [CV 5/10; 274/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50
# [CV 5/10; 274/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50;, score=(train=0.980, test=0.668) total time=10.5min
# [CV 8/10; 280/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20
# [CV 8/10; 280/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=20;, score=(train=0.986, test=0.646) total time=11.6min
# [CV 1/10; 287/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=55
# [CV 1/10; 287/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=55;, score=(train=0.979, test=0.876) total time= 7.3min
# [CV 1/10; 240/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=60;, score=(train=0.962, test=0.893) total time= 5.4min
# [CV 2/10; 246/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=30
# [CV 2/10; 246/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=30;, score=(train=0.972, test=0.941) total time= 5.2min
# [CV 10/10; 252/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=60
# [CV 10/10; 252/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=60;, score=(train=0.973, test=0.663) total time= 3.4min
# [CV 1/10; 258/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=30
# [CV 1/10; 258/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=30;, score=(train=0.975, test=0.890) total time= 5.8min
# ...
# [CV 8/10; 281/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25
# [CV 8/10; 281/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25;, score=(train=0.986, test=0.645) total time=11.3min
# [CV 6/10; 288/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60
# [CV 6/10; 288/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60;, score=(train=0.983, test=0.630) total time= 6.7min
# [CV 5/10; 288/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60;, score=(train=0.983, test=0.666) total time= 6.7min
# [CV 10/10; 217/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5
# [CV 10/10; 217/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5;, score=(train=0.963, test=0.696) total time= 5.6min
# [CV 5/10; 224/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40
# [CV 5/10; 224/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=40;, score=(train=0.962, test=0.687) total time=  44.0s
# [CV 1/10; 231/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15
# [CV 1/10; 231/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=15;, score=(train=0.965, test=0.904) total time= 5.7min
# [CV 5/10; 237/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45
# [CV 5/10; 237/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45;, score=(train=0.969, test=0.686) total time= 5.1min
# [CV 1/10; 244/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=20
# [CV 1/10; 244/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=20;, score=(train=0.972, test=0.897) total time= 2.0min
# [CV 5/10; 250/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50
# [CV 5/10; 250/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=50;, score=(train=0.973, test=0.677) total time= 4.9min
# [CV 1/10; 257/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=25
# [CV 1/10; 257/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=25;, score=(train=0.975, test=0.895) total time= 7.2min
# [CV 5/10; 263/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55
# [CV 5/10; 263/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55;, score=(train=0.976, test=0.669) total time= 8.8min
# [CV 8/10; 269/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25
# [CV 8/10; 269/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25;, score=(train=0.983, test=0.648) total time= 6.7min
# [CV 1/10; 276/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=60
# [CV 1/10; 276/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=60;, score=(train=0.978, test=0.881) total time= 8.0min
# [CV 5/10; 282/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30
# [CV 5/10; 282/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30;, score=(train=0.985, test=0.663) total time=11.0min
# [CV 8/10; 288/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60
# [CV 8/10; 288/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60;, score=(train=0.983, test=0.642) total time= 6.5min
# [CV 5/10; 198/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=30;, score=(train=0.916, test=0.730) total time= 1.4min
# [CV 9/10; 204/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60
# [CV 9/10; 204/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=100, reg_lambda=0, scale_pos_weight=60;, score=(train=0.913, test=0.726) total time= 1.4min
# [CV 3/10; 211/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35
# [CV 3/10; 211/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=200, reg_lambda=0, scale_pos_weight=35;, score=(train=0.931, test=0.963) total time= 2.8min
# [CV 7/10; 217/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5
# [CV 7/10; 217/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=5;, score=(train=0.962, test=0.698) total time= 5.5min
# [CV 9/10; 223/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35
# [CV 9/10; 223/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=400, reg_lambda=0, scale_pos_weight=35;, score=(train=0.961, test=0.689) total time=  53.0s
# [CV 6/10; 230/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10
# [CV 6/10; 230/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10;, score=(train=0.973, test=0.677) total time= 6.2min
# [CV 3/10; 237/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45
# [CV 3/10; 237/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45;, score=(train=0.964, test=0.940) total time= 4.6min
# [CV 3/10; 243/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15
# [CV 3/10; 243/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15;, score=(train=0.973, test=0.949) total time= 2.8min
# [CV 8/10; 249/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=45
# [CV 8/10; 249/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=45;, score=(train=0.974, test=0.655) total time= 4.7min
# [CV 5/10; 255/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15
# [CV 5/10; 255/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=15;, score=(train=0.982, test=0.677) total time= 6.7min
# [CV 2/10; 262/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50
# [CV 2/10; 262/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=50;, score=(train=0.975, test=0.932) total time= 5.1min
# [CV 6/10; 268/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=20
# [CV 6/10; 268/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=20;, score=(train=0.984, test=0.643) total time= 7.7min
# [CV 10/10; 274/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50
# [CV 10/10; 274/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=50;, score=(train=0.981, test=0.651) total time=10.0min
# [CV 4/10; 281/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25
# [CV 4/10; 281/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=25;, score=(train=0.983, test=0.875) total time=11.5min
# [CV 8/10; 287/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=55
# [CV 8/10; 287/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=55;, score=(train=0.983, test=0.643) total time= 7.2min
# [CV 8/10; 230/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=10;, score=(train=0.973, test=0.669) total time= 6.1min
# [CV 1/10; 237/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45
# [CV 1/10; 237/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=500, reg_lambda=0, scale_pos_weight=45;, score=(train=0.963, test=0.892) total time= 4.5min
# [CV 4/10; 243/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15
# [CV 4/10; 243/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=15;, score=(train=0.973, test=0.882) total time= 2.7min
# [CV 10/10; 249/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=45
# [CV 10/10; 249/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=600, reg_lambda=0, scale_pos_weight=45;, score=(train=0.973, test=0.663) total time= 5.1min
# [CV 9/10; 256/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=20
# [CV 9/10; 256/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=20;, score=(train=0.979, test=0.678) total time= 7.4min
# [CV 3/10; 263/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55
# [CV 3/10; 263/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=700, reg_lambda=0, scale_pos_weight=55;, score=(train=0.974, test=0.938) total time= 8.8min
# [CV 7/10; 269/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25
# [CV 7/10; 269/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25;, score=(train=0.984, test=0.660) total time= 6.8min
# [CV 2/10; 276/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=60
# [CV 2/10; 276/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=60;, score=(train=0.977, test=0.932) total time= 7.9min
# [CV 6/10; 282/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30
# [CV 6/10; 282/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30;, score=(train=0.986, test=0.633) total time=11.0min
# [CV 10/10; 288/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60
# [CV 10/10; 288/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60;, score=(train=0.983, test=0.645) total time= 6.5min
# [CV 5/10; 269/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=25;, score=(train=0.982, test=0.668) total time= 6.5min
# [CV 9/10; 275/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=55
# [CV 9/10; 275/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=800, reg_lambda=0, scale_pos_weight=55;, score=(train=0.980, test=0.667) total time= 8.3min
# [CV 3/10; 282/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30
# [CV 3/10; 282/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=30;, score=(train=0.982, test=0.935) total time=11.1min
# [CV 7/10; 288/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60
# [CV 7/10; 288/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60;, score=(train=0.983, test=0.649) total time= 6.7min
# [CV 1/10; 288/288] START gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60
# [CV 1/10; 288/288] END gamma=0, learning_rate=0.1, max_delta_step=2, max_depth=10, min_child_weight=2, n_estimators=900, reg_lambda=0, scale_pos_weight=60;, score=(train=0.980, test=0.879) total time= 7.1min

# %%
import time 

for i in range(10000):
    print("Sleep")
    time.sleep(60)
# Out:
# [CV 4/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 3/10; 629/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 3/10; 629/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 1/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 1/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.995, test=0.902) total time= 9.1min
# [CV 7/10; 587/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 10/10; 587/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 587/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 1/10; 588/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 1/10; 588/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 4/10; 588/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 4/10; 588/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 7/10; 588/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 7/10; 588/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 1/10; 589/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 1/10; 589/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 4/10; 589/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 589/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 7/10; 589/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 589/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 2/10; 590/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 590/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.911) total time=14.9min
# [CV 5/10; 285/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=8, min_child_weight=7, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.967, test=0.684) total time= 8.9min
# [CV 7/10; 407/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 7/10; 407/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.621) total time=19.4min
# [CV 3/10; 591/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 591/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.3s
# [CV 9/10; 591/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 591/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=2, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.658) total time=15.4min
# [CV 7/10; 626/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 7/10; 626/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 627/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 7/10; 627/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 7/10; 629/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 7/10; 629/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 4/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 4/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 8/10; 631/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 631/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.623) total time=10.0min
# [CV 2/10; 390/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 390/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 8/10; 391/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 391/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.3s
# [CV 3/10; 393/648] START gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 393/648] END gamma=0, learning_rate=0.1, max_delta_step=4, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.938) total time=13.3min
# [CV 2/10; 547/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 2/10; 547/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.989, test=0.926) total time=12.5min
# [CV 5/10; 609/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 609/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 2/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 2/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 8/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 6/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 6/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.601) total time=11.2min
# [CV 10/10; 606/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 607/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 2/10; 607/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 607/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 607/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 9/10; 607/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 9/10; 607/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 1/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 3/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 3/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 8/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 8/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 608/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 608/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 609/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 609/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   4.9s
# [CV 8/10; 609/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 8/10; 609/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 1/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 1/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 7/10; 610/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 610/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 5/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 10/10; 611/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 611/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.619) total time=11.2min
# [CV 2/10; 627/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 627/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=700, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 1/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 1/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 628/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 10/10; 628/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 629/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 629/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 10/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 1/10; 632/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 3/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 8/10; 634/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 634/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 3/10; 636/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 636/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=0.997, test=0.936) total time=10.2min
# [CV 9/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 5/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 3/10; 634/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 3/10; 634/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   4.7s
# [CV 2/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 9/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 9/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 9/10; 636/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 636/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 10/10; 637/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 10/10; 637/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 8/10; 638/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 8/10; 638/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.622) total time=10.4min
# [CV 1/10; 565/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 5/10; 565/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 565/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 8/10; 565/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 565/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 2/10; 566/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 566/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 5/10; 566/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 566/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 9/10; 566/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 9/10; 566/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 3/10; 567/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 567/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 10/10; 567/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 567/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 5/10; 568/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 568/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.2s
# [CV 7/10; 568/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 568/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.4s
# [CV 1/10; 569/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 1/10; 569/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=7, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=0.987, test=0.887) total time=11.1min
# [CV 7/10; 630/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 7/10; 630/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=800, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 5/10; 631/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 631/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 632/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 10/10; 632/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 10/10; 632/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 9/10; 633/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 633/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=900, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 634/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 634/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.1s
# [CV 6/10; 635/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 6/10; 635/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 636/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 636/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1000, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 5/10; 637/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 5/10; 637/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=7, n_estimators=1100, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.998, test=0.629) total time=10.6min
# [CV 7/10; 547/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 7/10; 547/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=10, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.991, test=0.633) total time=12.7min
# [CV 8/10; 616/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 8/10; 616/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 8/10; 617/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 8/10; 617/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 10/10; 618/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 10/10; 618/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.9s
# [CV 2/10; 620/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 2/10; 620/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 3/10; 621/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 3/10; 621/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 622/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 4/10; 622/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.844) total time=12.2min
# [CV 5/10; 614/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 5/10; 614/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 2/10; 615/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 2/10; 615/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 9/10; 615/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 9/10; 615/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1100, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 616/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 6/10; 616/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.8s
# [CV 6/10; 617/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 6/10; 617/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1200, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   5.0s
# [CV 3/10; 619/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 3/10; 619/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 4/10; 620/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855
# [CV 4/10; 620/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=1, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 5/10; 621/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855
# [CV 5/10; 621/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1300, reg_lambda=10, scale_pos_weight=42.12101505509855;, score=(train=nan, test=nan) total time=   3.7s
# [CV 6/10; 622/648] START gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855
# [CV 6/10; 622/648] END gamma=0, learning_rate=0.1, max_delta_step=6, max_depth=12, min_child_weight=5, n_estimators=1400, reg_lambda=0, scale_pos_weight=42.12101505509855;, score=(train=0.999, test=0.593) total time=12.2min
